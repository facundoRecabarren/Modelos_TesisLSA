# %% [markdown]
# # IMPORTS

# %%
import numpy as np
import os

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Masking, GRU, Dropout
from tensorflow.keras.callbacks import EarlyStopping #,TensorBoard

from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# # Datos Necesarios para los Modelos
#
# - Definicion de: Path/Ruta de alamcenamiento, Lista de Palabras, Cantidad de Personas, Cantidad de Videos por Persona y numero maximo de Frames.
# - Armado de DICCIONARIO que mapea VALOR(seña/palabra) a -> indice/número
# - Se almacenan en 2 variables los datos con los que se entrenaran los modelos "sequences" almacena en un arreglo los datos de cada video, "labels" es un arreglo de 0s y 1s que indica la clase a la que pertenece cada video. Esta celda puede ser reemplazada por la del apartado Limpieza de Datos (al final), el procesamiento es el mismo pero se tiene en cuenta "frames sucios".

# %%
STORE_PATH2 = os.path.join('LSA64_data')

# Lista de Palabras con las que se armarán las oraciones, no se encuentran las 64 palabras
# signs_list = ['opaco', 'rojo', 'verde', 'amarillo', 'brillante', 'celeste', 'colores', 'rosa', 'mujer', 'enemigo', 'hijo', 'hombre', 'lejos','cajón','aprender','llamar','espumadera','amargo','dulce','leche','agua','comida','Argentina','Uruguay','pais','donde','apellido','burla','cumpleanos','desayuno','foto','hambre','mapa','moneda','musica','nave espacial','ninguno','nombre','paciencia','perfume','sordo','trampa','arroz','asado','caramelo','chicle','fideos','yogurt','aceptar','agradecer','apagar','aparecer','aterrizar','atrapar','ayudar','bailar','bañarse','comprar','copiar','correr','darse cuenta','dar','encontrar']
signs_list = ['nacer','comida','brillante', 'mujer', 'hijo', 'hombre', 'lejos', 'aprender', 'espumadera','amargo','leche','Uruguay','pais','donde','ninguno','nombre','perfume','sordo','comprar','encontrar', 'nave espacial']
numberOfPersons = 10
numberOfVideosPerPerson = 5

maximumNumberOfFrames = 201
# maximumNumberOfFrames = 101

# %%
# DICCIONARIO que mapea VALOR(seña/palabra) a -> indice/número
sign_labels = {label : index for index, label in enumerate(signs_list)}
print(sign_labels)
# Out:
# {'nacer': 0, 'comida': 1, 'brillante': 2, 'mujer': 3, 'hijo': 4, 'hombre': 5, 'lejos': 6, 'aprender': 7, 'espumadera': 8, 'amargo': 9, 'leche': 10, 'Uruguay': 11, 'pais': 12, 'donde': 13, 'ninguno': 14, 'nombre': 15, 'perfume': 16, 'sordo': 17, 'comprar': 18, 'encontrar': 19, 'nave espacial': 20}

# %%
# LA EJECUCION DE ESTA CELDA PUEDE SER REEMPLAZADA POR LA DEL APARTADO LIMPIEZA DE DATOS
sequences, labels = [],[]
for sign in range(len(signs_list)):
    for personNumber in range(numberOfPersons-1):
        for videoNumber in range(numberOfVideosPerPerson):
            result = np.load(os.path.join(STORE_PATH2, signs_list[sign], f'''0{str(personNumber)}_0{str(videoNumber)}.npy'''))
            resultWithoutFace = []
# salto de a 1 frame para simular un "muestreo" de cada video y no usar todos los frames, no es un muestreo probabilistico
            for index in range(0,201,2):
#                 NO TOMO EN CUENTA LOS DATOS DE LA CARA
                resultWithoutFace.append(result[index][936:])
            sequences.append(resultWithoutFace)
            labels.append(sign_labels[signs_list[sign]])
            
sequences = np.array(sequences)
labels = to_categorical(labels).astype(int)

# %% [markdown]
# # DEFINICIÓN DE MODELOS

# %%
model = Sequential()
model.add(Masking(mask_value=paddingValue, input_shape=(201, 1086)))
model.add(LSTM(64, return_sequences=True, activation='tanh', input_shape=(40, 1086)))
model.add(LSTM(128, return_sequences=True, activation='tanh'))
model.add(LSTM(64, return_sequences=False, activation='tanh'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(32, activation='tanh'))
model.add(Dense(np.array(signs_list).shape[0], activation='softmax'))

# %%
# CUARTO MODELO USADO GRU - GRU
paddingValue = 3
model = Sequential()
model.add(Masking(mask_value=paddingValue, input_shape=(201, 1086)))
model.add(GRU(128, return_sequences=True, activation='tanh'))
model.add(GRU(128, return_sequences=False, activation='tanh'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(np.array(signs_list).shape[0], activation='softmax'))

# %%
# QUINTO MODELO USADO
paddingValue = 3
model = Sequential()
model.add(Masking(mask_value=paddingValue, input_shape=(201, 1086)))
model.add(LSTM(128, return_sequences=True, activation='tanh'))
model.add(LSTM(128, return_sequences=False, activation='tanh'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(32, activation='tanh'))
model.add(Dense(np.array(signs_list).shape[0], activation='softmax'))

# %%
paddingValue = 3
model = Sequential()
model.add(Masking(mask_value=paddingValue, input_shape=(201, 150)))
model.add(GRU(128, return_sequences=True, activation='tanh'))
model.add(GRU(128, return_sequences=True, activation='tanh'))
model.add(GRU(64, return_sequences=False, activation='tanh'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(np.array(signs_list).shape[0], activation='softmax'))

# %%
# 30/11 pruebo para ver si con LSTM tambien demora 5 segundos sin datos de cara
paddingValue = 3
model = Sequential()
model.add(Masking(mask_value=paddingValue, input_shape=(201, 150)))
model.add(Dropout(0.4))
model.add(LSTM(128, return_sequences=True, activation='tanh'))
model.add(Dropout(0.4))
model.add(LSTM(128, return_sequences=False, activation='tanh'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(32, activation='tanh'))
model.add(Dense(np.array(signs_list).shape[0], activation='softmax'))

# %%
# Armo un modelo para entrenar habiendo armado los arreglos con un salto de frames (sampleo o muestreo)
paddingValue = 3
model = Sequential()
model.add(Masking(mask_value=paddingValue, input_shape=(101, 150)))
model.add(Dropout(0.4))
model.add(LSTM(128, return_sequences=True, activation='tanh'))
model.add(Dropout(0.4))
model.add(LSTM(128, return_sequences=False, activation='tanh'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(32, activation='tanh'))
model.add(Dense(np.array(signs_list).shape[0], activation='softmax'))

# %%
model.summary()

# %% [markdown]
# # COMPILACIÓN DEL MODELO

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
esLoss = EarlyStopping(monitor='loss', mode='min', verbose=1, patience=30, min_delta=0)

# %%
xTrain, xTest, yTrain, yTest = train_test_split(sequences, labels , test_size=0.05, random_state=1)

model.fit(xTrain, yTrain, validation_data=(xTest,yTest), epochs=500, callbacks=[esLoss])
# Out:
# Epoch 1/500
# 29/29 [==============================] - 11s 234ms/step - loss: 3.0508 - categorical_accuracy: 0.0678 - val_loss: 3.1425 - val_categorical_accuracy: 0.0833
# Epoch 2/500
# 29/29 [==============================] - 5s 184ms/step - loss: 2.8679 - categorical_accuracy: 0.1425 - val_loss: 2.6530 - val_categorical_accuracy: 0.2292
# Epoch 3/500
# 29/29 [==============================] - 5s 179ms/step - loss: 2.4966 - categorical_accuracy: 0.2115 - val_loss: 2.4912 - val_categorical_accuracy: 0.2083
# Epoch 4/500
# 29/29 [==============================] - 5s 174ms/step - loss: 2.3407 - categorical_accuracy: 0.3062 - val_loss: 2.2580 - val_categorical_accuracy: 0.2500
# Epoch 5/500
# 29/29 [==============================] - 5s 181ms/step - loss: 2.0849 - categorical_accuracy: 0.3511 - val_loss: 2.3258 - val_categorical_accuracy: 0.2708
# Epoch 6/500
# 29/29 [==============================] - 5s 143ms/step - loss: 1.9620 - categorical_accuracy: 0.3764 - val_loss: 1.8464 - val_categorical_accuracy: 0.3958
# Epoch 7/500
# 29/29 [==============================] - 4s 138ms/step - loss: 1.7786 - categorical_accuracy: 0.4441 - val_loss: 2.1214 - val_categorical_accuracy: 0.3125
# Epoch 8/500
# 29/29 [==============================] - 5s 177ms/step - loss: 2.2458 - categorical_accuracy: 0.3085 - val_loss: 1.8098 - val_categorical_accuracy: 0.4792
# Epoch 9/500
# 29/29 [==============================] - 4s 140ms/step - loss: 2.1827 - categorical_accuracy: 0.3336 - val_loss: 1.9273 - val_categorical_accuracy: 0.3125
# Epoch 10/500
# 29/29 [==============================] - 4s 139ms/step - loss: 1.7976 - categorical_accuracy: 0.4270 - val_loss: 1.6810 - val_categorical_accuracy: 0.4583
# Epoch 11/500
# 29/29 [==============================] - 5s 177ms/step - loss: 1.6874 - categorical_accuracy: 0.4428 - val_loss: 1.6550 - val_categorical_accuracy: 0.5417
# Epoch 12/500
# 29/29 [==============================] - 5s 144ms/step - loss: 1.6485 - categorical_accuracy: 0.4583 - val_loss: 1.6094 - val_categorical_accuracy: 0.5000
# Epoch 13/500
# 29/29 [==============================] - 5s 177ms/step - loss: 1.4358 - categorical_accuracy: 0.5606 - val_loss: 1.5781 - val_categorical_accuracy: 0.5625
# Epoch 14/500
# 29/29 [==============================] - 5s 179ms/step - loss: 1.7686 - categorical_accuracy: 0.4107 - val_loss: 1.5090 - val_categorical_accuracy: 0.5625
# Epoch 15/500
# 29/29 [==============================] - 4s 143ms/step - loss: 1.4337 - categorical_accuracy: 0.5253 - val_loss: 1.5568 - val_categorical_accuracy: 0.5625
# Epoch 16/500
# 29/29 [==============================] - 5s 174ms/step - loss: 1.4691 - categorical_accuracy: 0.5198 - val_loss: 1.3655 - val_categorical_accuracy: 0.5833
# Epoch 17/500
# 29/29 [==============================] - 5s 175ms/step - loss: 1.2274 - categorical_accuracy: 0.6161 - val_loss: 1.3172 - val_categorical_accuracy: 0.5417
# Epoch 18/500
# 29/29 [==============================] - 5s 174ms/step - loss: 1.2159 - categorical_accuracy: 0.6357 - val_loss: 1.8257 - val_categorical_accuracy: 0.5417
# Epoch 19/500
# 29/29 [==============================] - 5s 180ms/step - loss: 1.2837 - categorical_accuracy: 0.6138 - val_loss: 1.4111 - val_categorical_accuracy: 0.5417
# Epoch 20/500
# 29/29 [==============================] - 5s 174ms/step - loss: 1.5186 - categorical_accuracy: 0.5030 - val_loss: 1.2250 - val_categorical_accuracy: 0.6667
# Epoch 21/500
# 29/29 [==============================] - 5s 171ms/step - loss: 1.1892 - categorical_accuracy: 0.6125 - val_loss: 1.2474 - val_categorical_accuracy: 0.6667
# Epoch 22/500
# 29/29 [==============================] - 5s 179ms/step - loss: 1.2694 - categorical_accuracy: 0.6031 - val_loss: 1.2342 - val_categorical_accuracy: 0.5833
# Epoch 23/500
# 29/29 [==============================] - 5s 175ms/step - loss: 1.2725 - categorical_accuracy: 0.5911 - val_loss: 1.5171 - val_categorical_accuracy: 0.6042
# Epoch 24/500
# 29/29 [==============================] - 5s 172ms/step - loss: 1.8692 - categorical_accuracy: 0.4678 - val_loss: 1.5310 - val_categorical_accuracy: 0.5625
# Epoch 25/500
# 29/29 [==============================] - 5s 175ms/step - loss: 1.3059 - categorical_accuracy: 0.5870 - val_loss: 1.0937 - val_categorical_accuracy: 0.7292
# Epoch 26/500
# 29/29 [==============================] - 5s 180ms/step - loss: 1.1432 - categorical_accuracy: 0.6249 - val_loss: 1.0519 - val_categorical_accuracy: 0.7083
# Epoch 27/500
# 29/29 [==============================] - 4s 145ms/step - loss: 1.0492 - categorical_accuracy: 0.6730 - val_loss: 1.1473 - val_categorical_accuracy: 0.6250
# Epoch 28/500
# 29/29 [==============================] - 4s 106ms/step - loss: 0.9385 - categorical_accuracy: 0.6976 - val_loss: 0.8627 - val_categorical_accuracy: 0.7708
# Epoch 29/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.8478 - categorical_accuracy: 0.7507 - val_loss: 0.9202 - val_categorical_accuracy: 0.7083
# Epoch 30/500
# 29/29 [==============================] - 5s 179ms/step - loss: 1.0248 - categorical_accuracy: 0.6891 - val_loss: 3.2891 - val_categorical_accuracy: 0.2083
# Epoch 31/500
# 29/29 [==============================] - 4s 144ms/step - loss: 2.9016 - categorical_accuracy: 0.2341 - val_loss: 1.8090 - val_categorical_accuracy: 0.4583
# Epoch 32/500
# 29/29 [==============================] - 5s 142ms/step - loss: 1.8747 - categorical_accuracy: 0.3907 - val_loss: 1.4055 - val_categorical_accuracy: 0.5208
# Epoch 33/500
# 29/29 [==============================] - 5s 177ms/step - loss: 1.4878 - categorical_accuracy: 0.4779 - val_loss: 1.3325 - val_categorical_accuracy: 0.5625
# Epoch 34/500
# 29/29 [==============================] - 5s 178ms/step - loss: 1.3098 - categorical_accuracy: 0.5449 - val_loss: 1.0783 - val_categorical_accuracy: 0.6458
# Epoch 35/500
# 29/29 [==============================] - 5s 177ms/step - loss: 1.3824 - categorical_accuracy: 0.5221 - val_loss: 1.0757 - val_categorical_accuracy: 0.6667
# Epoch 36/500
# 29/29 [==============================] - 4s 110ms/step - loss: 0.9590 - categorical_accuracy: 0.6925 - val_loss: 0.9382 - val_categorical_accuracy: 0.6667
# Epoch 37/500
# 29/29 [==============================] - 5s 141ms/step - loss: 1.0467 - categorical_accuracy: 0.6499 - val_loss: 1.1531 - val_categorical_accuracy: 0.6042
# Epoch 38/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.9811 - categorical_accuracy: 0.6759 - val_loss: 1.0468 - val_categorical_accuracy: 0.6458
# Epoch 39/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.8501 - categorical_accuracy: 0.7595 - val_loss: 1.1811 - val_categorical_accuracy: 0.6250
# Epoch 40/500
# 29/29 [==============================] - 5s 175ms/step - loss: 1.3164 - categorical_accuracy: 0.5868 - val_loss: 1.0719 - val_categorical_accuracy: 0.6667
# Epoch 41/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.8962 - categorical_accuracy: 0.7052 - val_loss: 1.0469 - val_categorical_accuracy: 0.7083
# Epoch 42/500
# 29/29 [==============================] - 4s 108ms/step - loss: 1.2070 - categorical_accuracy: 0.6135 - val_loss: 1.0489 - val_categorical_accuracy: 0.6458
# Epoch 43/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.7436 - categorical_accuracy: 0.7685 - val_loss: 0.8442 - val_categorical_accuracy: 0.6875
# Epoch 44/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.7023 - categorical_accuracy: 0.7731 - val_loss: 0.7969 - val_categorical_accuracy: 0.7917
# Epoch 45/500
# 29/29 [==============================] - 5s 172ms/step - loss: 0.6710 - categorical_accuracy: 0.7986 - val_loss: 0.7817 - val_categorical_accuracy: 0.7917
# Epoch 46/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.6025 - categorical_accuracy: 0.8092 - val_loss: 1.0891 - val_categorical_accuracy: 0.6458
# Epoch 47/500
# 29/29 [==============================] - 5s 136ms/step - loss: 0.6291 - categorical_accuracy: 0.8075 - val_loss: 0.8736 - val_categorical_accuracy: 0.7708
# Epoch 48/500
# 29/29 [==============================] - 4s 141ms/step - loss: 0.5410 - categorical_accuracy: 0.8147 - val_loss: 0.8964 - val_categorical_accuracy: 0.7083
# Epoch 49/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.5732 - categorical_accuracy: 0.8167 - val_loss: 0.9806 - val_categorical_accuracy: 0.6667
# Epoch 50/500
# 29/29 [==============================] - 6s 204ms/step - loss: 0.7997 - categorical_accuracy: 0.7349 - val_loss: 0.7806 - val_categorical_accuracy: 0.6875
# Epoch 51/500
# 29/29 [==============================] - 5s 187ms/step - loss: 0.6596 - categorical_accuracy: 0.7739 - val_loss: 0.6516 - val_categorical_accuracy: 0.7708
# Epoch 52/500
# 29/29 [==============================] - 5s 189ms/step - loss: 0.6290 - categorical_accuracy: 0.7853 - val_loss: 0.6167 - val_categorical_accuracy: 0.7917
# Epoch 53/500
# 29/29 [==============================] - 4s 111ms/step - loss: 0.7789 - categorical_accuracy: 0.7560 - val_loss: 0.6412 - val_categorical_accuracy: 0.8333
# Epoch 54/500
# 29/29 [==============================] - 4s 143ms/step - loss: 0.5782 - categorical_accuracy: 0.8104 - val_loss: 0.6964 - val_categorical_accuracy: 0.7708
# Epoch 55/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.5671 - categorical_accuracy: 0.7914 - val_loss: 0.6701 - val_categorical_accuracy: 0.7708
# Epoch 56/500
# 29/29 [==============================] - 5s 171ms/step - loss: 0.4767 - categorical_accuracy: 0.8314 - val_loss: 0.5634 - val_categorical_accuracy: 0.8750
# Epoch 57/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.4217 - categorical_accuracy: 0.8668 - val_loss: 0.5620 - val_categorical_accuracy: 0.8125
# Epoch 58/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.4936 - categorical_accuracy: 0.8234 - val_loss: 0.5017 - val_categorical_accuracy: 0.8542
# Epoch 59/500
# 29/29 [==============================] - 5s 183ms/step - loss: 0.4417 - categorical_accuracy: 0.8593 - val_loss: 0.5642 - val_categorical_accuracy: 0.7500
# Epoch 60/500
# 29/29 [==============================] - 5s 180ms/step - loss: 0.5042 - categorical_accuracy: 0.8238 - val_loss: 0.5756 - val_categorical_accuracy: 0.7917
# Epoch 61/500
# 29/29 [==============================] - 4s 135ms/step - loss: 0.4466 - categorical_accuracy: 0.8543 - val_loss: 0.5371 - val_categorical_accuracy: 0.8333
# Epoch 62/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.5128 - categorical_accuracy: 0.8233 - val_loss: 0.4324 - val_categorical_accuracy: 0.8542
# Epoch 63/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.4248 - categorical_accuracy: 0.8486 - val_loss: 0.4255 - val_categorical_accuracy: 0.7917
# Epoch 64/500
# 29/29 [==============================] - 5s 147ms/step - loss: 0.4383 - categorical_accuracy: 0.8778 - val_loss: 0.4691 - val_categorical_accuracy: 0.7917
# Epoch 65/500
# 29/29 [==============================] - 3s 108ms/step - loss: 0.4620 - categorical_accuracy: 0.8517 - val_loss: 0.5029 - val_categorical_accuracy: 0.8333
# Epoch 66/500
# 29/29 [==============================] - 5s 173ms/step - loss: 0.4276 - categorical_accuracy: 0.8387 - val_loss: 0.4826 - val_categorical_accuracy: 0.7917
# Epoch 67/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.4315 - categorical_accuracy: 0.8771 - val_loss: 0.3607 - val_categorical_accuracy: 0.9167
# Epoch 68/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.3842 - categorical_accuracy: 0.8715 - val_loss: 0.5209 - val_categorical_accuracy: 0.7917
# Epoch 69/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.4463 - categorical_accuracy: 0.8507 - val_loss: 0.4312 - val_categorical_accuracy: 0.8125
# Epoch 70/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.3698 - categorical_accuracy: 0.8670 - val_loss: 0.5448 - val_categorical_accuracy: 0.8333
# Epoch 71/500
# 29/29 [==============================] - 5s 180ms/step - loss: 0.7969 - categorical_accuracy: 0.7518 - val_loss: 0.6956 - val_categorical_accuracy: 0.7500
# Epoch 72/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.4970 - categorical_accuracy: 0.8305 - val_loss: 0.5106 - val_categorical_accuracy: 0.8125
# Epoch 73/500
# 29/29 [==============================] - 5s 139ms/step - loss: 1.3319 - categorical_accuracy: 0.5980 - val_loss: 0.8943 - val_categorical_accuracy: 0.6875
# Epoch 74/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.8312 - categorical_accuracy: 0.7093 - val_loss: 1.1305 - val_categorical_accuracy: 0.6875
# Epoch 75/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.8588 - categorical_accuracy: 0.7241 - val_loss: 0.6576 - val_categorical_accuracy: 0.7083
# Epoch 76/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.7370 - categorical_accuracy: 0.7454 - val_loss: 1.1899 - val_categorical_accuracy: 0.5833
# Epoch 77/500
# 29/29 [==============================] - 5s 139ms/step - loss: 0.8563 - categorical_accuracy: 0.6975 - val_loss: 0.7591 - val_categorical_accuracy: 0.7500
# Epoch 78/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.6524 - categorical_accuracy: 0.7958 - val_loss: 0.7272 - val_categorical_accuracy: 0.7500
# Epoch 79/500
# 29/29 [==============================] - 4s 107ms/step - loss: 0.7355 - categorical_accuracy: 0.7411 - val_loss: 0.6984 - val_categorical_accuracy: 0.7292
# Epoch 80/500
# 29/29 [==============================] - 5s 181ms/step - loss: 0.5530 - categorical_accuracy: 0.8239 - val_loss: 0.5839 - val_categorical_accuracy: 0.7708
# Epoch 81/500
# 29/29 [==============================] - 5s 140ms/step - loss: 0.5039 - categorical_accuracy: 0.8232 - val_loss: 0.6237 - val_categorical_accuracy: 0.7292
# Epoch 82/500
# 29/29 [==============================] - 5s 180ms/step - loss: 0.4362 - categorical_accuracy: 0.8586 - val_loss: 0.4561 - val_categorical_accuracy: 0.8542
# Epoch 83/500
# 29/29 [==============================] - 4s 141ms/step - loss: 0.4222 - categorical_accuracy: 0.8548 - val_loss: 0.4834 - val_categorical_accuracy: 0.8125
# Epoch 84/500
# 29/29 [==============================] - 4s 143ms/step - loss: 0.4497 - categorical_accuracy: 0.8425 - val_loss: 0.9456 - val_categorical_accuracy: 0.7292
# Epoch 85/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.5947 - categorical_accuracy: 0.7928 - val_loss: 0.4513 - val_categorical_accuracy: 0.8542
# Epoch 86/500
# 29/29 [==============================] - 5s 146ms/step - loss: 0.4796 - categorical_accuracy: 0.8366 - val_loss: 0.5686 - val_categorical_accuracy: 0.8125
# Epoch 87/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.4037 - categorical_accuracy: 0.8741 - val_loss: 0.5353 - val_categorical_accuracy: 0.8333
# Epoch 88/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.3535 - categorical_accuracy: 0.8651 - val_loss: 0.5171 - val_categorical_accuracy: 0.7917
# Epoch 89/500
# 29/29 [==============================] - 5s 187ms/step - loss: 0.5261 - categorical_accuracy: 0.8090 - val_loss: 0.5857 - val_categorical_accuracy: 0.8333
# Epoch 90/500
# 29/29 [==============================] - 5s 180ms/step - loss: 0.4420 - categorical_accuracy: 0.8466 - val_loss: 0.5099 - val_categorical_accuracy: 0.8542
# Epoch 91/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.4590 - categorical_accuracy: 0.8570 - val_loss: 0.5348 - val_categorical_accuracy: 0.8333
# Epoch 92/500
# 29/29 [==============================] - 4s 138ms/step - loss: 0.7302 - categorical_accuracy: 0.7580 - val_loss: 0.6356 - val_categorical_accuracy: 0.7917
# Epoch 93/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.9687 - categorical_accuracy: 0.7139 - val_loss: 0.6602 - val_categorical_accuracy: 0.7917
# Epoch 94/500
# 29/29 [==============================] - 5s 180ms/step - loss: 0.5359 - categorical_accuracy: 0.8149 - val_loss: 0.5278 - val_categorical_accuracy: 0.7917
# Epoch 95/500
# 29/29 [==============================] - 4s 143ms/step - loss: 0.5579 - categorical_accuracy: 0.8224 - val_loss: 0.5107 - val_categorical_accuracy: 0.8125
# Epoch 96/500
# 29/29 [==============================] - 4s 140ms/step - loss: 1.6601 - categorical_accuracy: 0.6458 - val_loss: 3.4990 - val_categorical_accuracy: 0.1250
# Epoch 97/500
# 29/29 [==============================] - 5s 172ms/step - loss: 3.2243 - categorical_accuracy: 0.1102 - val_loss: 2.4776 - val_categorical_accuracy: 0.2292
# Epoch 98/500
# 29/29 [==============================] - 5s 178ms/step - loss: 2.5094 - categorical_accuracy: 0.1847 - val_loss: 2.1436 - val_categorical_accuracy: 0.2708
# Epoch 99/500
# 29/29 [==============================] - 5s 178ms/step - loss: 2.1898 - categorical_accuracy: 0.2603 - val_loss: 1.8106 - val_categorical_accuracy: 0.3958
# Epoch 100/500
# 29/29 [==============================] - 5s 177ms/step - loss: 2.0939 - categorical_accuracy: 0.3125 - val_loss: 1.8030 - val_categorical_accuracy: 0.3958
# Epoch 101/500
# 29/29 [==============================] - 5s 175ms/step - loss: 1.8095 - categorical_accuracy: 0.3731 - val_loss: 1.5961 - val_categorical_accuracy: 0.4167
# Epoch 102/500
# 29/29 [==============================] - 5s 179ms/step - loss: 2.3404 - categorical_accuracy: 0.2708 - val_loss: 1.4845 - val_categorical_accuracy: 0.4375
# Epoch 103/500
# 29/29 [==============================] - 5s 177ms/step - loss: 1.4738 - categorical_accuracy: 0.5052 - val_loss: 1.0849 - val_categorical_accuracy: 0.6667
# Epoch 104/500
# 29/29 [==============================] - 5s 174ms/step - loss: 1.2991 - categorical_accuracy: 0.5686 - val_loss: 0.9174 - val_categorical_accuracy: 0.6250
# Epoch 105/500
# 29/29 [==============================] - 5s 182ms/step - loss: 0.8261 - categorical_accuracy: 0.7211 - val_loss: 0.5649 - val_categorical_accuracy: 0.7917
# Epoch 106/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.5967 - categorical_accuracy: 0.8154 - val_loss: 0.5714 - val_categorical_accuracy: 0.7917
# Epoch 107/500
# 29/29 [==============================] - 5s 181ms/step - loss: 0.6564 - categorical_accuracy: 0.7795 - val_loss: 0.6052 - val_categorical_accuracy: 0.7708
# Epoch 108/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.6208 - categorical_accuracy: 0.7878 - val_loss: 0.7586 - val_categorical_accuracy: 0.7500
# Epoch 109/500
# 29/29 [==============================] - 5s 181ms/step - loss: 0.7028 - categorical_accuracy: 0.7497 - val_loss: 0.7599 - val_categorical_accuracy: 0.7083
# Epoch 110/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.5736 - categorical_accuracy: 0.7997 - val_loss: 0.6180 - val_categorical_accuracy: 0.8333
# Epoch 111/500
# 29/29 [==============================] - 5s 140ms/step - loss: 0.5088 - categorical_accuracy: 0.8270 - val_loss: 0.4573 - val_categorical_accuracy: 0.8542
# Epoch 112/500
# 29/29 [==============================] - 5s 187ms/step - loss: 0.4553 - categorical_accuracy: 0.8357 - val_loss: 0.4444 - val_categorical_accuracy: 0.8542
# Epoch 113/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.3502 - categorical_accuracy: 0.8891 - val_loss: 0.4471 - val_categorical_accuracy: 0.8333
# Epoch 114/500
# 29/29 [==============================] - 5s 142ms/step - loss: 0.3784 - categorical_accuracy: 0.8630 - val_loss: 0.3565 - val_categorical_accuracy: 0.8750
# Epoch 115/500
# 29/29 [==============================] - 4s 143ms/step - loss: 0.3754 - categorical_accuracy: 0.8809 - val_loss: 0.3863 - val_categorical_accuracy: 0.8542
# Epoch 116/500
# 29/29 [==============================] - 5s 140ms/step - loss: 0.3612 - categorical_accuracy: 0.8823 - val_loss: 0.4182 - val_categorical_accuracy: 0.8125
# Epoch 117/500
# 29/29 [==============================] - 5s 173ms/step - loss: 0.3850 - categorical_accuracy: 0.8732 - val_loss: 0.4120 - val_categorical_accuracy: 0.7917
# Epoch 118/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.3497 - categorical_accuracy: 0.8888 - val_loss: 0.6661 - val_categorical_accuracy: 0.7708
# Epoch 119/500
# 29/29 [==============================] - 5s 179ms/step - loss: 2.1288 - categorical_accuracy: 0.4433 - val_loss: 0.9589 - val_categorical_accuracy: 0.5833
# Epoch 120/500
# 29/29 [==============================] - 5s 173ms/step - loss: 1.0144 - categorical_accuracy: 0.6216 - val_loss: 0.6729 - val_categorical_accuracy: 0.7917
# Epoch 121/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.7377 - categorical_accuracy: 0.7622 - val_loss: 0.6223 - val_categorical_accuracy: 0.8125
# Epoch 122/500
# 29/29 [==============================] - 5s 172ms/step - loss: 0.7522 - categorical_accuracy: 0.7190 - val_loss: 0.6794 - val_categorical_accuracy: 0.7708
# Epoch 123/500
# 29/29 [==============================] - 5s 180ms/step - loss: 0.5921 - categorical_accuracy: 0.7831 - val_loss: 0.6721 - val_categorical_accuracy: 0.8125
# Epoch 124/500
# 29/29 [==============================] - 5s 139ms/step - loss: 0.9869 - categorical_accuracy: 0.6679 - val_loss: 0.6993 - val_categorical_accuracy: 0.7500
# Epoch 125/500
# 29/29 [==============================] - 5s 181ms/step - loss: 0.7330 - categorical_accuracy: 0.7764 - val_loss: 0.5388 - val_categorical_accuracy: 0.8125
# Epoch 126/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.6511 - categorical_accuracy: 0.7784 - val_loss: 0.8383 - val_categorical_accuracy: 0.7083
# Epoch 127/500
# 29/29 [==============================] - 5s 176ms/step - loss: 1.1929 - categorical_accuracy: 0.6260 - val_loss: 0.5928 - val_categorical_accuracy: 0.7708
# Epoch 128/500
# 29/29 [==============================] - 5s 182ms/step - loss: 0.7235 - categorical_accuracy: 0.7375 - val_loss: 0.6895 - val_categorical_accuracy: 0.7500
# Epoch 129/500
# 29/29 [==============================] - 5s 183ms/step - loss: 0.5140 - categorical_accuracy: 0.8287 - val_loss: 0.5723 - val_categorical_accuracy: 0.7917
# Epoch 130/500
# 29/29 [==============================] - 5s 141ms/step - loss: 0.4813 - categorical_accuracy: 0.8446 - val_loss: 0.5751 - val_categorical_accuracy: 0.7917
# Epoch 131/500
# 29/29 [==============================] - 5s 181ms/step - loss: 0.5388 - categorical_accuracy: 0.8231 - val_loss: 0.5194 - val_categorical_accuracy: 0.8958
# Epoch 132/500
# 29/29 [==============================] - 5s 142ms/step - loss: 0.4116 - categorical_accuracy: 0.8493 - val_loss: 0.7087 - val_categorical_accuracy: 0.7708
# Epoch 133/500
# 29/29 [==============================] - 5s 181ms/step - loss: 1.1413 - categorical_accuracy: 0.6424 - val_loss: 0.5947 - val_categorical_accuracy: 0.7917
# Epoch 134/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.5020 - categorical_accuracy: 0.8396 - val_loss: 0.8048 - val_categorical_accuracy: 0.7083
# Epoch 135/500
# 29/29 [==============================] - 5s 143ms/step - loss: 0.5771 - categorical_accuracy: 0.8030 - val_loss: 0.7942 - val_categorical_accuracy: 0.6875
# Epoch 136/500
# 29/29 [==============================] - 5s 183ms/step - loss: 0.4517 - categorical_accuracy: 0.8289 - val_loss: 0.6653 - val_categorical_accuracy: 0.7500
# Epoch 137/500
# 29/29 [==============================] - 4s 138ms/step - loss: 0.4038 - categorical_accuracy: 0.8608 - val_loss: 0.6327 - val_categorical_accuracy: 0.7292
# Epoch 138/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.3583 - categorical_accuracy: 0.8755 - val_loss: 0.4907 - val_categorical_accuracy: 0.7708
# Epoch 139/500
# 29/29 [==============================] - 5s 173ms/step - loss: 0.3744 - categorical_accuracy: 0.8681 - val_loss: 0.4733 - val_categorical_accuracy: 0.8333
# Epoch 140/500
# 29/29 [==============================] - 4s 142ms/step - loss: 0.3164 - categorical_accuracy: 0.8983 - val_loss: 0.4688 - val_categorical_accuracy: 0.7917
# Epoch 141/500
# 29/29 [==============================] - 5s 144ms/step - loss: 0.3422 - categorical_accuracy: 0.8823 - val_loss: 0.4987 - val_categorical_accuracy: 0.7917
# Epoch 142/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.3519 - categorical_accuracy: 0.8832 - val_loss: 0.4472 - val_categorical_accuracy: 0.8125
# Epoch 143/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.3036 - categorical_accuracy: 0.8930 - val_loss: 0.4173 - val_categorical_accuracy: 0.8542
# Epoch 144/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.2853 - categorical_accuracy: 0.9055 - val_loss: 0.3160 - val_categorical_accuracy: 0.8542
# Epoch 145/500
# 29/29 [==============================] - 5s 187ms/step - loss: 0.2866 - categorical_accuracy: 0.9004 - val_loss: 0.3318 - val_categorical_accuracy: 0.8750
# Epoch 146/500
# 29/29 [==============================] - 5s 182ms/step - loss: 0.2439 - categorical_accuracy: 0.9191 - val_loss: 0.4687 - val_categorical_accuracy: 0.8542
# Epoch 147/500
# 29/29 [==============================] - 4s 142ms/step - loss: 0.3016 - categorical_accuracy: 0.8916 - val_loss: 0.3571 - val_categorical_accuracy: 0.8750
# Epoch 148/500
# 29/29 [==============================] - 4s 143ms/step - loss: 0.2625 - categorical_accuracy: 0.9227 - val_loss: 0.4994 - val_categorical_accuracy: 0.7917
# Epoch 149/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.2890 - categorical_accuracy: 0.8937 - val_loss: 0.4180 - val_categorical_accuracy: 0.8333
# Epoch 150/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.2590 - categorical_accuracy: 0.9115 - val_loss: 0.4160 - val_categorical_accuracy: 0.8333
# Epoch 151/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.2728 - categorical_accuracy: 0.9071 - val_loss: 0.4937 - val_categorical_accuracy: 0.7708
# Epoch 152/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.3422 - categorical_accuracy: 0.8787 - val_loss: 0.3234 - val_categorical_accuracy: 0.8750
# Epoch 153/500
# 29/29 [==============================] - 5s 142ms/step - loss: 0.6139 - categorical_accuracy: 0.8066 - val_loss: 0.5002 - val_categorical_accuracy: 0.8333
# Epoch 154/500
# 29/29 [==============================] - 4s 143ms/step - loss: 0.3528 - categorical_accuracy: 0.8769 - val_loss: 0.4168 - val_categorical_accuracy: 0.8333
# Epoch 155/500
# 29/29 [==============================] - 4s 142ms/step - loss: 0.3007 - categorical_accuracy: 0.9002 - val_loss: 0.3516 - val_categorical_accuracy: 0.8333
# Epoch 156/500
# 29/29 [==============================] - 5s 140ms/step - loss: 0.2737 - categorical_accuracy: 0.9138 - val_loss: 0.3218 - val_categorical_accuracy: 0.8750
# Epoch 157/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.2449 - categorical_accuracy: 0.9027 - val_loss: 0.3169 - val_categorical_accuracy: 0.8750
# Epoch 158/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.2436 - categorical_accuracy: 0.9217 - val_loss: 0.3872 - val_categorical_accuracy: 0.8750
# Epoch 159/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.2733 - categorical_accuracy: 0.9077 - val_loss: 0.3321 - val_categorical_accuracy: 0.8333
# Epoch 160/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.2058 - categorical_accuracy: 0.9362 - val_loss: 0.2766 - val_categorical_accuracy: 0.8958
# Epoch 161/500
# 29/29 [==============================] - 5s 144ms/step - loss: 0.3023 - categorical_accuracy: 0.8949 - val_loss: 0.4565 - val_categorical_accuracy: 0.8125
# Epoch 162/500
# 29/29 [==============================] - 5s 171ms/step - loss: 0.6122 - categorical_accuracy: 0.7859 - val_loss: 0.4495 - val_categorical_accuracy: 0.8333
# Epoch 163/500
# 29/29 [==============================] - 5s 180ms/step - loss: 0.3595 - categorical_accuracy: 0.8811 - val_loss: 0.3784 - val_categorical_accuracy: 0.8542
# Epoch 164/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.2898 - categorical_accuracy: 0.8815 - val_loss: 0.3436 - val_categorical_accuracy: 0.8542
# Epoch 165/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.2321 - categorical_accuracy: 0.9160 - val_loss: 0.2994 - val_categorical_accuracy: 0.8542
# Epoch 166/500
# 29/29 [==============================] - 5s 142ms/step - loss: 0.2586 - categorical_accuracy: 0.9096 - val_loss: 0.3264 - val_categorical_accuracy: 0.8750
# Epoch 167/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.2597 - categorical_accuracy: 0.8895 - val_loss: 0.2554 - val_categorical_accuracy: 0.9167
# Epoch 168/500
# 29/29 [==============================] - 5s 173ms/step - loss: 0.2425 - categorical_accuracy: 0.9122 - val_loss: 0.3568 - val_categorical_accuracy: 0.8542
# Epoch 169/500
# 29/29 [==============================] - 5s 173ms/step - loss: 0.2425 - categorical_accuracy: 0.9027 - val_loss: 0.4274 - val_categorical_accuracy: 0.8750
# Epoch 170/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.6956 - categorical_accuracy: 0.8159 - val_loss: 0.4699 - val_categorical_accuracy: 0.7708
# Epoch 171/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.3524 - categorical_accuracy: 0.8672 - val_loss: 0.4110 - val_categorical_accuracy: 0.7708
# Epoch 172/500
# 29/29 [==============================] - 5s 181ms/step - loss: 0.2852 - categorical_accuracy: 0.9020 - val_loss: 0.4584 - val_categorical_accuracy: 0.8125
# Epoch 173/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.3157 - categorical_accuracy: 0.8923 - val_loss: 0.3394 - val_categorical_accuracy: 0.8542
# Epoch 174/500
# 29/29 [==============================] - 5s 181ms/step - loss: 0.2835 - categorical_accuracy: 0.9048 - val_loss: 0.3326 - val_categorical_accuracy: 0.8750
# Epoch 175/500
# 29/29 [==============================] - 5s 173ms/step - loss: 0.2627 - categorical_accuracy: 0.9068 - val_loss: 0.3322 - val_categorical_accuracy: 0.9167
# Epoch 176/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.2656 - categorical_accuracy: 0.9101 - val_loss: 0.2235 - val_categorical_accuracy: 0.9583
# Epoch 177/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.2858 - categorical_accuracy: 0.9015 - val_loss: 0.2640 - val_categorical_accuracy: 0.9167
# Epoch 178/500
# 29/29 [==============================] - 5s 142ms/step - loss: 0.2116 - categorical_accuracy: 0.9137 - val_loss: 0.2953 - val_categorical_accuracy: 0.8750
# Epoch 179/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.2207 - categorical_accuracy: 0.9100 - val_loss: 0.3354 - val_categorical_accuracy: 0.8750
# Epoch 180/500
# 29/29 [==============================] - 5s 171ms/step - loss: 0.2561 - categorical_accuracy: 0.9289 - val_loss: 0.4231 - val_categorical_accuracy: 0.8542
# Epoch 181/500
# 29/29 [==============================] - 5s 173ms/step - loss: 0.2243 - categorical_accuracy: 0.9077 - val_loss: 0.3497 - val_categorical_accuracy: 0.8750
# Epoch 182/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.1936 - categorical_accuracy: 0.9449 - val_loss: 0.3843 - val_categorical_accuracy: 0.8542
# Epoch 183/500
# 29/29 [==============================] - 4s 142ms/step - loss: 0.2054 - categorical_accuracy: 0.9223 - val_loss: 0.3363 - val_categorical_accuracy: 0.8542
# Epoch 184/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.1919 - categorical_accuracy: 0.9361 - val_loss: 0.3542 - val_categorical_accuracy: 0.7917
# Epoch 185/500
# 29/29 [==============================] - 5s 172ms/step - loss: 0.2196 - categorical_accuracy: 0.9308 - val_loss: 0.3909 - val_categorical_accuracy: 0.8125
# Epoch 186/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.2217 - categorical_accuracy: 0.9184 - val_loss: 0.5374 - val_categorical_accuracy: 0.8333
# Epoch 187/500
# 29/29 [==============================] - 4s 139ms/step - loss: 0.1840 - categorical_accuracy: 0.9363 - val_loss: 0.3001 - val_categorical_accuracy: 0.8542
# Epoch 188/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.2265 - categorical_accuracy: 0.9055 - val_loss: 0.4636 - val_categorical_accuracy: 0.8125
# Epoch 189/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.2133 - categorical_accuracy: 0.9291 - val_loss: 0.3049 - val_categorical_accuracy: 0.8750
# Epoch 190/500
# 29/29 [==============================] - 5s 173ms/step - loss: 0.4291 - categorical_accuracy: 0.8504 - val_loss: 0.4242 - val_categorical_accuracy: 0.8125
# Epoch 191/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.6343 - categorical_accuracy: 0.8140 - val_loss: 0.8693 - val_categorical_accuracy: 0.7083
# Epoch 192/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.4579 - categorical_accuracy: 0.8357 - val_loss: 0.4438 - val_categorical_accuracy: 0.8125
# Epoch 193/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.3577 - categorical_accuracy: 0.8650 - val_loss: 0.2252 - val_categorical_accuracy: 0.9375
# Epoch 194/500
# 29/29 [==============================] - 4s 143ms/step - loss: 0.2676 - categorical_accuracy: 0.8979 - val_loss: 0.2331 - val_categorical_accuracy: 0.9167
# Epoch 195/500
# 29/29 [==============================] - 5s 182ms/step - loss: 0.2135 - categorical_accuracy: 0.9252 - val_loss: 0.2439 - val_categorical_accuracy: 0.9167
# Epoch 196/500
# 29/29 [==============================] - 5s 182ms/step - loss: 0.2298 - categorical_accuracy: 0.9179 - val_loss: 0.1820 - val_categorical_accuracy: 0.9375
# Epoch 197/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.2347 - categorical_accuracy: 0.9070 - val_loss: 0.3469 - val_categorical_accuracy: 0.8750
# Epoch 198/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.1824 - categorical_accuracy: 0.9192 - val_loss: 0.2261 - val_categorical_accuracy: 0.9375
# Epoch 199/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.2740 - categorical_accuracy: 0.9012 - val_loss: 0.2545 - val_categorical_accuracy: 0.8958
# Epoch 200/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.1817 - categorical_accuracy: 0.9343 - val_loss: 0.1882 - val_categorical_accuracy: 0.9167
# Epoch 201/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.1538 - categorical_accuracy: 0.9465 - val_loss: 0.1858 - val_categorical_accuracy: 0.8958
# Epoch 202/500
# 29/29 [==============================] - 4s 136ms/step - loss: 0.1514 - categorical_accuracy: 0.9560 - val_loss: 0.2163 - val_categorical_accuracy: 0.9167
# Epoch 203/500
# 29/29 [==============================] - 4s 142ms/step - loss: 0.1692 - categorical_accuracy: 0.9425 - val_loss: 0.2450 - val_categorical_accuracy: 0.8750
# Epoch 204/500
# 29/29 [==============================] - 5s 181ms/step - loss: 0.1678 - categorical_accuracy: 0.9320 - val_loss: 0.2159 - val_categorical_accuracy: 0.8958
# Epoch 205/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.1658 - categorical_accuracy: 0.9428 - val_loss: 0.2930 - val_categorical_accuracy: 0.8542
# Epoch 206/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.1853 - categorical_accuracy: 0.9326 - val_loss: 0.2849 - val_categorical_accuracy: 0.9375
# Epoch 207/500
# 29/29 [==============================] - 4s 142ms/step - loss: 0.1708 - categorical_accuracy: 0.9391 - val_loss: 0.2788 - val_categorical_accuracy: 0.8958
# Epoch 208/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.2472 - categorical_accuracy: 0.9122 - val_loss: 0.3128 - val_categorical_accuracy: 0.9167
# Epoch 209/500
# 29/29 [==============================] - 5s 142ms/step - loss: 0.3042 - categorical_accuracy: 0.8921 - val_loss: 0.1778 - val_categorical_accuracy: 0.9583
# Epoch 210/500
# 29/29 [==============================] - 5s 143ms/step - loss: 0.3758 - categorical_accuracy: 0.8504 - val_loss: 0.3229 - val_categorical_accuracy: 0.8750
# Epoch 211/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.2533 - categorical_accuracy: 0.9175 - val_loss: 0.2551 - val_categorical_accuracy: 0.8958
# Epoch 212/500
# 29/29 [==============================] - 5s 184ms/step - loss: 0.2181 - categorical_accuracy: 0.9169 - val_loss: 0.4162 - val_categorical_accuracy: 0.8333
# Epoch 213/500
# 29/29 [==============================] - 6s 202ms/step - loss: 0.1615 - categorical_accuracy: 0.9385 - val_loss: 0.2050 - val_categorical_accuracy: 0.9375
# Epoch 214/500
# 29/29 [==============================] - 4s 137ms/step - loss: 0.1762 - categorical_accuracy: 0.9330 - val_loss: 0.3423 - val_categorical_accuracy: 0.8333
# Epoch 215/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.1749 - categorical_accuracy: 0.9243 - val_loss: 0.3384 - val_categorical_accuracy: 0.8750
# Epoch 216/500
# 29/29 [==============================] - 4s 141ms/step - loss: 0.3313 - categorical_accuracy: 0.8867 - val_loss: 0.3878 - val_categorical_accuracy: 0.8542
# Epoch 217/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.2392 - categorical_accuracy: 0.9181 - val_loss: 0.2879 - val_categorical_accuracy: 0.8750
# Epoch 218/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.1877 - categorical_accuracy: 0.9381 - val_loss: 0.2751 - val_categorical_accuracy: 0.8958
# Epoch 219/500
# 29/29 [==============================] - 5s 178ms/step - loss: 0.1971 - categorical_accuracy: 0.9235 - val_loss: 0.2659 - val_categorical_accuracy: 0.8958
# Epoch 220/500
# 29/29 [==============================] - 5s 180ms/step - loss: 0.1525 - categorical_accuracy: 0.9435 - val_loss: 0.3653 - val_categorical_accuracy: 0.8750
# Epoch 221/500
# 29/29 [==============================] - 5s 172ms/step - loss: 0.1592 - categorical_accuracy: 0.9477 - val_loss: 0.2988 - val_categorical_accuracy: 0.8958
# Epoch 222/500
# 29/29 [==============================] - 5s 180ms/step - loss: 0.1700 - categorical_accuracy: 0.9415 - val_loss: 0.4383 - val_categorical_accuracy: 0.7917
# Epoch 223/500
# 29/29 [==============================] - 5s 147ms/step - loss: 0.2248 - categorical_accuracy: 0.9113 - val_loss: 0.1737 - val_categorical_accuracy: 0.9375
# Epoch 224/500
# 29/29 [==============================] - 5s 172ms/step - loss: 0.1621 - categorical_accuracy: 0.9478 - val_loss: 0.2062 - val_categorical_accuracy: 0.9375
# Epoch 225/500
# 29/29 [==============================] - 5s 181ms/step - loss: 0.1984 - categorical_accuracy: 0.9301 - val_loss: 0.2001 - val_categorical_accuracy: 0.9167
# Epoch 226/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.1339 - categorical_accuracy: 0.9507 - val_loss: 0.2628 - val_categorical_accuracy: 0.8750
# Epoch 227/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.1241 - categorical_accuracy: 0.9622 - val_loss: 0.2682 - val_categorical_accuracy: 0.8958
# Epoch 228/500
# 29/29 [==============================] - 5s 173ms/step - loss: 0.1607 - categorical_accuracy: 0.9347 - val_loss: 0.4697 - val_categorical_accuracy: 0.8333
# Epoch 229/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.1935 - categorical_accuracy: 0.9291 - val_loss: 0.2245 - val_categorical_accuracy: 0.9167
# Epoch 230/500
# 29/29 [==============================] - 4s 145ms/step - loss: 0.1464 - categorical_accuracy: 0.9436 - val_loss: 0.1908 - val_categorical_accuracy: 0.9375
# Epoch 231/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.1045 - categorical_accuracy: 0.9695 - val_loss: 0.2598 - val_categorical_accuracy: 0.8958
# Epoch 232/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.1543 - categorical_accuracy: 0.9459 - val_loss: 0.2720 - val_categorical_accuracy: 0.8750
# Epoch 233/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.2081 - categorical_accuracy: 0.9286 - val_loss: 0.3315 - val_categorical_accuracy: 0.8542
# Epoch 234/500
# 29/29 [==============================] - 4s 108ms/step - loss: 0.1679 - categorical_accuracy: 0.9415 - val_loss: 0.3293 - val_categorical_accuracy: 0.8958
# Epoch 235/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.1284 - categorical_accuracy: 0.9589 - val_loss: 0.3354 - val_categorical_accuracy: 0.8958
# Epoch 236/500
# 29/29 [==============================] - 5s 186ms/step - loss: 0.1151 - categorical_accuracy: 0.9693 - val_loss: 0.2597 - val_categorical_accuracy: 0.8958
# Epoch 237/500
# 29/29 [==============================] - 5s 141ms/step - loss: 0.1290 - categorical_accuracy: 0.9562 - val_loss: 0.3048 - val_categorical_accuracy: 0.9167
# Epoch 238/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.1189 - categorical_accuracy: 0.9641 - val_loss: 0.2612 - val_categorical_accuracy: 0.9167
# Epoch 239/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.1290 - categorical_accuracy: 0.9486 - val_loss: 0.2960 - val_categorical_accuracy: 0.8750
# Epoch 240/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.0985 - categorical_accuracy: 0.9721 - val_loss: 0.2292 - val_categorical_accuracy: 0.9167
# Epoch 241/500
# 29/29 [==============================] - 4s 140ms/step - loss: 0.1357 - categorical_accuracy: 0.9497 - val_loss: 0.2486 - val_categorical_accuracy: 0.8958
# Epoch 242/500
# 29/29 [==============================] - 4s 145ms/step - loss: 0.1410 - categorical_accuracy: 0.9538 - val_loss: 0.3243 - val_categorical_accuracy: 0.8542
# Epoch 243/500
# 29/29 [==============================] - 4s 145ms/step - loss: 0.4780 - categorical_accuracy: 0.8450 - val_loss: 0.4488 - val_categorical_accuracy: 0.8542
# Epoch 244/500
# 29/29 [==============================] - 5s 194ms/step - loss: 0.3553 - categorical_accuracy: 0.8763 - val_loss: 0.3027 - val_categorical_accuracy: 0.8958
# Epoch 245/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.1878 - categorical_accuracy: 0.9321 - val_loss: 0.2743 - val_categorical_accuracy: 0.8750
# Epoch 246/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.1871 - categorical_accuracy: 0.9282 - val_loss: 0.2677 - val_categorical_accuracy: 0.8958
# Epoch 247/500
# 29/29 [==============================] - 5s 174ms/step - loss: 0.1764 - categorical_accuracy: 0.9401 - val_loss: 0.1851 - val_categorical_accuracy: 0.9167
# Epoch 248/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.3262 - categorical_accuracy: 0.8996 - val_loss: 0.2598 - val_categorical_accuracy: 0.8958
# Epoch 249/500
# 29/29 [==============================] - 5s 179ms/step - loss: 0.1641 - categorical_accuracy: 0.9483 - val_loss: 0.2727 - val_categorical_accuracy: 0.8542
# Epoch 250/500
# 29/29 [==============================] - 4s 142ms/step - loss: 0.1510 - categorical_accuracy: 0.9439 - val_loss: 0.4707 - val_categorical_accuracy: 0.8125
# Epoch 251/500
# 29/29 [==============================] - 5s 146ms/step - loss: 0.1600 - categorical_accuracy: 0.9371 - val_loss: 0.2033 - val_categorical_accuracy: 0.9167
# Epoch 252/500
# 29/29 [==============================] - 4s 145ms/step - loss: 0.1369 - categorical_accuracy: 0.9537 - val_loss: 0.2003 - val_categorical_accuracy: 0.9375
# Epoch 253/500
# 29/29 [==============================] - 5s 173ms/step - loss: 0.1517 - categorical_accuracy: 0.9531 - val_loss: 0.2233 - val_categorical_accuracy: 0.9167
# Epoch 254/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.1363 - categorical_accuracy: 0.9611 - val_loss: 0.2036 - val_categorical_accuracy: 0.9375
# Epoch 255/500
# 29/29 [==============================] - 5s 176ms/step - loss: 0.0992 - categorical_accuracy: 0.9702 - val_loss: 0.2676 - val_categorical_accuracy: 0.9167
# Epoch 256/500
# 29/29 [==============================] - 4s 141ms/step - loss: 0.1919 - categorical_accuracy: 0.9410 - val_loss: 0.3387 - val_categorical_accuracy: 0.8958
# Epoch 257/500
# 29/29 [==============================] - 4s 137ms/step - loss: 0.8717 - categorical_accuracy: 0.7784 - val_loss: 0.6632 - val_categorical_accuracy: 0.7500
# Epoch 258/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.5149 - categorical_accuracy: 0.8172 - val_loss: 0.5063 - val_categorical_accuracy: 0.8542
# Epoch 259/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.6161 - categorical_accuracy: 0.8039 - val_loss: 0.2874 - val_categorical_accuracy: 0.8958
# Epoch 260/500
# 29/29 [==============================] - 5s 142ms/step - loss: 0.3150 - categorical_accuracy: 0.8974 - val_loss: 0.3246 - val_categorical_accuracy: 0.8542
# Epoch 261/500
# 29/29 [==============================] - 5s 181ms/step - loss: 0.2562 - categorical_accuracy: 0.9186 - val_loss: 0.2476 - val_categorical_accuracy: 0.8750
# Epoch 262/500
# 29/29 [==============================] - 5s 182ms/step - loss: 0.1534 - categorical_accuracy: 0.9494 - val_loss: 0.2871 - val_categorical_accuracy: 0.8542
# Epoch 263/500
# 29/29 [==============================] - 5s 182ms/step - loss: 0.1741 - categorical_accuracy: 0.9362 - val_loss: 0.1953 - val_categorical_accuracy: 0.8750
# Epoch 264/500
# 29/29 [==============================] - 4s 148ms/step - loss: 0.1740 - categorical_accuracy: 0.9408 - val_loss: 0.8579 - val_categorical_accuracy: 0.7500
# Epoch 265/500
# 29/29 [==============================] - 5s 177ms/step - loss: 0.2947 - categorical_accuracy: 0.8892 - val_loss: 0.3439 - val_categorical_accuracy: 0.8750
# Epoch 266/500
# 29/29 [==============================] - 5s 173ms/step - loss: 0.2044 - categorical_accuracy: 0.9222 - val_loss: 0.4683 - val_categorical_accuracy: 0.8333
# Epoch 267/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.2441 - categorical_accuracy: 0.9185 - val_loss: 0.1929 - val_categorical_accuracy: 0.9167
# Epoch 268/500
# 29/29 [==============================] - 3s 111ms/step - loss: 0.1624 - categorical_accuracy: 0.9506 - val_loss: 0.3593 - val_categorical_accuracy: 0.8958
# Epoch 269/500
# 29/29 [==============================] - 5s 175ms/step - loss: 0.2186 - categorical_accuracy: 0.9323 - val_loss: 0.2629 - val_categorical_accuracy: 0.8750
# Epoch 270/500
# 29/29 [==============================] - 4s 145ms/step - loss: 0.1483 - categorical_accuracy: 0.9399 - val_loss: 0.2445 - val_categorical_accuracy: 0.8958
# Epoch 00270: early stopping

# %% [markdown]
# # EVALUACION DEL MODELO
#
# - Se evalua el modelo entrenado sobre todos los videos
# - Se evalua el modelo sobre los datos que se separaron para Testeo (xTest, yTest)

# %%
# evaluo las predicciones del modelo sobre TODO el set de datos de los videos procesados
threshold08 = 0.8
threshold09 = 0.9

totalProcessed = 0

predictedOkay08 = 0
predictedOkay09 = 0

for sign in range(len(signs_list)):
    for personNumber in range(numberOfPersons):
        for videoNumber in range(numberOfVideosPerPerson):
            videoData = np.load(os.path.join(STORE_PATH2, signs_list[sign], f'''0{str(personNumber)}_0{str(videoNumber)}.npy'''))
            # resultWithDistances = []
            # for index in range(201):
            #   resultWithDistances.append(getEuclideanDistances(videoData[index]))
            # print(f'''VIDEO: LSA64_data/{signs_list[sign]}/0{personNumber}_0{videoNumber}''')
            # videoData2 = []
            # for index in range(201):
                # if (index % 2 != 0):
                    # videoData2.append(videoData[index])
            resultWithoutFace = []
            for index in range(201):
                resultWithoutFace.append(videoData[index][936:])
#                 resultWithoutFace.append(videoData[index])
            response = model.predict(np.expand_dims(resultWithoutFace, axis=0))
            if (np.max(response) > threshold08):
#                 print('Seña leída: '+ signs_list[sign] + '------  Predice: ' + signs_list[np.argmax(response)])
                if (signs_list[sign] == signs_list[np.argmax(response)]):
                    predictedOkay08 = predictedOkay08 + 1
                    if (np.max(response) > threshold09):
                        predictedOkay09 = predictedOkay09 + 1
            totalProcessed = totalProcessed + 1
            
print(totalProcessed)
print(predictedOkay08)
print(str((predictedOkay08/totalProcessed)*100)+'%')
print(predictedOkay09)
print(str((predictedOkay09/totalProcessed)*100)+'%')
# Out:
# 1050
# 705
# 67.14285714285714%
# 664
# 63.23809523809524%

# %%
j = 0
i = 0
list_of_wrongs = []
for index in range(len(xTest)):
    res = model.predict(np.expand_dims(xTest[index], axis=0))
    predicted = signs_list[np.argmax(res[0])]
    expected_result = signs_list[np.argmax(yTest[index])]
#     print(predicted)
#     print(expected_result)
    j += 1
    if (predicted == expected_result):
        i+=1
    else:
        list_of_wrongs.append(predicted + expected_result)
print(f"total:{j}, ok: {i}, mal {j - i}")
# Out:
# total:48, ok: 43, mal 5

# %% [markdown]
# # GUARDA/CARGA DE MODELO
# En caso de que el modelo funcione de manera correcta se pueden almacenar los pesos, sino tambien se pueden cargar (descomentar SAVE para guardar, de lo contrario descomentar LOAD para cargar)

# %%
# model.save('modelWeightsLSA64_500_1t.h5')
model.load_weights('modelos_pesos/GRUx3-GPUmia.h5')

# %% [markdown]
# # PRUEBA EN TIEMPO REAL DEL MODELO
#
# Primer celda contiene funciones necesarias para mostrar puntos en imagen, deteccion de persona con MediaPipe (ya definidas y usadas en OBtencion de Datos.ipynb)

# %%
import cv2
import mediapipe

mp_holistic = mediapipe.solutions.holistic
mp_drawing = mediapipe.solutions.drawing_utils

def mediapipe_detection(image, model):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image.flags.writeable = False
    results = model.process(image)                 #prediction from a frame
    image.flags.writeable = True
    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
    return image, results

leftHandStyles = [0,138,255,2,1] #naranja
rightHandStyles = [231,217,0,2,1] #celeste
faceStyles = [80,110,10,0,1]
poseStyles = [70,100,5,2,1]
def draw_styled_landmarks(image, results):
    #     FACE
    mp_drawing.draw_landmarks(
        image,
        results.face_landmarks,
        mp_holistic.FACEMESH_CONTOURS,
        mp_drawing.DrawingSpec(color=(faceStyles[0],faceStyles[1],faceStyles[2]), thickness=faceStyles[3], circle_radius=faceStyles[4])
    )
    #     POSE/BODY
    mp_drawing.draw_landmarks(
        image,
        results.pose_landmarks,
        mp_holistic.POSE_CONNECTIONS,
        mp_drawing.DrawingSpec(color=(poseStyles[0],poseStyles[1],poseStyles[2]), thickness=poseStyles[3], circle_radius=poseStyles[4])
    )
    #     LEFT HAND
    mp_drawing.draw_landmarks(
        image,
        results.left_hand_landmarks,
        mp_holistic.HAND_CONNECTIONS,
        mp_drawing.DrawingSpec(color=(leftHandStyles[0],leftHandStyles[1],leftHandStyles[2]), thickness=leftHandStyles[3], circle_radius=leftHandStyles[4])
    )
    #     RIGHT HAND
    mp_drawing.draw_landmarks(
        image,
        results.right_hand_landmarks,
        mp_holistic.HAND_CONNECTIONS,
        mp_drawing.DrawingSpec(color=(rightHandStyles[0],rightHandStyles[1],rightHandStyles[2]), thickness=rightHandStyles[3], circle_radius=rightHandStyles[4])
    )

def array_from_landmarks(results):
    # LEFT HAND array
    # len(results.left_hand_landmarks.landmark) = 21 landmarks for each hand, with 2 coordinates each landmark
    if (results.left_hand_landmarks):
        leftHandLandmarks = np.array([[result.x, result.y] for result in results.left_hand_landmarks.landmark]).flatten()
    else:
        leftHandLandmarks = np.zeros(21*2)


    # RIGHT HAND array
    # len(results.right_hand_landmarks.landmark) -> same for right hand
    if (results.right_hand_landmarks):
        rightHandLandmarks = np.array([[result.x, result.y ] for result in results.right_hand_landmarks.landmark]).flatten()
    else:
        rightHandLandmarks = np.zeros(21*2)


    # POSE array
    # len(results.pose_landmarks.landmark) -> 33 landmarks of 2 coordinates each one (X, Y)
    if (results.pose_landmarks):
        poseLandmarks = np.array([[result.x, result.y] for result in results.pose_landmarks.landmark]).flatten()
    else:
        poseLandmarks = np.zeros(33*2)


    # FACE array
    # len(results.face_landmarks.landmark) -> 468 landmarks of 2 coordinates each one
    if (results.face_landmarks):
        faceLandmarks = np.array([[result.x, result.y] for result in results.face_landmarks.landmark]).flatten()
    else:
        faceLandmarks = np.zeros(468*2)
        
    return np.concatenate((faceLandmarks, poseLandmarks, leftHandLandmarks, rightHandLandmarks))

# %%
sequence = [] #store 40 frames like the framesPerVideo
sentence = [] #store a list of 'words'
threshold = 0.7


caption = cv2.VideoCapture(0)
caption.set(cv2.CAP_PROP_FPS, 60)
i = 0
with mp_holistic.Holistic(static_image_mode=False, min_detection_confidence=0.5, min_tracking_confidence=0.5) as holisticModel:
    while caption.isOpened():
        i = i + 1
        ret, frame = caption.read()
        
#         PARA REDIMENSIONAR IMAGEN
#         ret, normalFrame = caption.read()
#         frame = cv2.resize(normalFrame, (1920, 1080))
        image, results = mediapipe_detection(frame, holisticModel)
        draw_styled_landmarks(image, results)
        
        keypoints = array_from_landmarks(results)
        sequence.append(keypoints[936:]) #le quito datos de la cara
#         sequence.append(keypoints)
        
#         if len(sequence) == maximumNumberOfFrames:
        res = model.predict(np.expand_dims(sequence, axis=0))
        res = res[0]

        if res[np.argmax(res)] > threshold:
#           Si predice igual a ultima palabra predicha no se coloca
            if len(sentence) > 0:
                if signs_list[np.argmax(res)] != sentence[-1]:
                    sentence.append(signs_list[np.argmax(res)])
            else:
                sentence.append(signs_list[np.argmax(res)])
#         if len(sentence) > 5:
#             sentence = sentence[-5:]

        cv2.putText(image, ' '.join(sentence), (10,20), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (255,255,255), 2)
        cv2.putText(image, 'Frame °: ' + str(i), (10,50), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (255,255,255), 2)
        cv2.imshow('Predicting sign..', image)
    
        if cv2.waitKey(10) & 0xFF == ord('q'): #press 'q' to break
            break
    caption.release()
    cv2.destroyAllWindows()
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 201, 150) for input KerasTensor(type_spec=TensorSpec(shape=(None, 201, 150), dtype=tf.float32, name='masking_2_input'), name='masking_2_input', description="created by layer 'masking_2_input'"), but it was called on an input with incompatible shape (None, 1, 150).

# %% [markdown]
# # LIMPIEZA DE LOS DATOS GUARDADOS
#
# En esta seccion defino una funcion que salte los frames que representan datos "limpios" teniendo en cuenta en este caso como datos limpios a:
# - Frames que no han detectado como MINIMO 1 mano, cara y posicion. Si falta alguna de estas 3 componentes el frame no se toma en cuenta.
#
# - Se debe actualizar el valor de maximumNumberOfFrames segun el caso que se desee probar.

# %%
def isFrameClean(frame):
    if ((frame[0] != 0.0 and frame[1] != 0.0 and frame[934] != 0.0 and frame[935] != 0.0) and 
        (frame[958] != 0.0 and frame[959] != 0.0 and frame[960] != 0.0 and frame[961] != 0.0) and 
        ((frame[1018] != 0.0 and frame[1019] != 0.0 and frame[1003] != 0.0 and frame[1004] != 0.0) or 
        (frame[1044] != 0.0 and frame[1045] != 0.0 and frame[1084] != 0.0 and frame[1085] != 0.0)) 
        ):
        return True
    return False


paddingValue = 3

def paddData(sequence):
    paddLength = maximumNumberOfFrames - len(sequence)
    return np.pad(sequence, [(0,paddLength),(0,0)], mode='constant', constant_values=paddingValue)

# %%
# CELDA QUE PERMITE EL REEMPLAZO NOMBRADO ARRIBA DEL PROYECTO
sequences, labels = [],[]
for sign in range(len(signs_list)):
    for personNumber in range(numberOfPersons-1):
        for videoNumber in range(numberOfVideosPerPerson):
            result = np.load(os.path.join(STORE_PATH2, signs_list[sign], f'''0{str(personNumber)}_0{str(videoNumber)}.npy'''))
            resultWithFace = []

#             el 201 es la longitud de frames con la que se almacenaron todos los videos

            for index in range(0,201,2):#me salto de a 1 frame para probar con muestreo de cada video y no usar todos los frames, no es un muestreo probabilistico
#                 resultWithoutFace.append(result[index][936:])
                resultWithFace.append(result[index])
#             al haberme salteado de a 2 frames, de los 201 me quedan 67, 
#             entonces ahora limpio los frames "sucios" y paddeo con valor 3 hasta completar los 67
#             despues debería probar que en lugar de completar con valor de padding 3, usar el 
#             frame previo o siguiente al que se quitó.

# PUEDO LIMPIAR LOS FRAMES ANTES DE AGREGARLOS A resultWithFace arriba ↑

            cleanedResults = []
            for frame in range(len(resultWithFace)):
#                 En caso de frame "sucio" no debería reemplazarlo por dato de padding, por que el padding debería 
#                 ir solo al final, por lo que tomo un frame de izquierda o derecha.
#                 Sino no reemplazo con nada y hago el padding al final como está ahora
                if (isFrameClean(resultWithFace[frame])):
                    cleanedResults.append(resultWithFace[frame][936:])
            if (len(cleanedResults) != maximumNumberOfFrames):
                cleanedResults = paddData(cleanedResults)
            sequences.append(cleanedResults)
            labels.append(sign_labels[signs_list[sign]])
sequences = np.array(sequences)
labels = to_categorical(labels).astype(int)
