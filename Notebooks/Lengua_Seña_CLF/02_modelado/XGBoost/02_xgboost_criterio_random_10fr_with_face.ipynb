# %%
import numpy as np
import pandas as pd
import joblib # Para guardar modelo

# Datos
from sklearn import preprocessing
from sklearn.model_selection import (
    train_test_split,
    cross_validate,
    RepeatedStratifiedKFold
)

# MODELO
import xgboost as xgb

# EVALUACION
from sklearn.metrics import (
    roc_auc_score as roc_auc, 
    precision_score as precision,  
    f1_score as f1, 
    recall_score as recall,
    accuracy_score as accuracy, 
    brier_score_loss as brier_loss, 
    average_precision_score as average_precision, 
    fbeta_score as fbeta,
    make_scorer,
    classification_report
)

from scipy.stats import ks_2samp

# OPTIMIZACION
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# # Funciones Varias

# %%
def f2(y_true, y_pred):
    return fbeta(y_true=y_true, y_pred=y_pred, beta=2, average='macro')


def f05(y_true, y_pred):
    return fbeta(y_true=y_true, y_pred=y_pred, beta=0.5, average='macro')


def ks_stat(y, yhat):
    """
    Métrica de KS
    """
    return ks_2samp(yhat[y == 1], yhat[y != 1]).statistic

def eval_model_cv(X, y, model, metricas_, n_splits_=6, n_repeats_=5):
    """
    Evaluación del modelo en cross validation, con N folds y N repeticiones.
    """
    cv = RepeatedStratifiedKFold(
        n_splits=n_splits_, n_repeats=n_repeats_, random_state=42
    )
    scores = cross_validate(model, X, y, scoring=metricas_, cv=cv)
    eval_df = pd.DataFrame(scores)
    
    tabla = (
        eval_df.drop(["fit_time", "score_time"], axis=1)
        .rename(columns=lambda x: x.replace('test_', ''))
        .describe()
        .T.drop("count", axis=1)
        #.style.format(precision=2)
    )

    dicc = tabla['mean'].round(2).to_dict()
    dicc = {x.replace('test_', ''): v for x, v in dicc.items()}


    tabla = tabla.style.format(precision=2)


    return tabla, dicc

def metrics(y, X, pipe):
    metrics_inferences = {
        precision: "label",
        recall: "label",
        f1: "label",
        f05: "label",
        f2: "label",
        accuracy: "label",
        roc_auc: "proba",
    }
    
    preds = pd.DataFrame(
                        {"y_true": y, 
                        "y_pred_prob": [i[1] for i in pipe.predict_proba(X)], 
                        "y_pred_class": pipe.predict(X)}
                    )
    preds.fillna(0)
    
    test_metrics = {}
    test_metrics['precision'] = precision(preds["y_true"], preds["y_pred_class"], average='macro')
    test_metrics['recall'] = recall(preds["y_true"], preds["y_pred_class"], average='macro')
    test_metrics['f1'] = f1(preds["y_true"], preds["y_pred_class"], average='macro')
    test_metrics['f05'] = f05(preds["y_true"], preds["y_pred_class"])
    test_metrics['f2'] = f2(preds["y_true"], preds["y_pred_class"])
    test_metrics['accuracy'] = accuracy(preds["y_true"], preds["y_pred_class"])        

    del preds

    table_metrics = pd.DataFrame({'metrica':test_metrics.keys(), 'valor':test_metrics.values()})
    table_metrics['valor'] = round(table_metrics['valor'],2)

    return table_metrics, test_metrics


import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from IPython.display import set_matplotlib_formats

def plot_matrix_confusion(X_test,y_test,le,model):
    y_pred = model.predict(X_test)

    conf_mat = confusion_matrix(y_test, y_pred)
    #Valores normalizados
    conf_mat_norm = conf_mat.astype('float') / conf_mat.sum(axis=1)[:, np.newaxis]

    # Crear una figura con un tamaño personalizado

    plt.figure(figsize=(16, 16))
    ax= plt.subplot()
    sns.heatmap(conf_mat_norm, annot=True,fmt='.2f',cmap="OrRd")

    # labels, title and ticks
    ax.set_xlabel('Predicted labels')
    ax.set_ylabel('True labels')
    ax.set_title('Confusion Matrix')
    ax.xaxis.set_ticklabels(le.classes_) 
    ax.yaxis.set_ticklabels(le.classes_)
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
                rotation_mode="anchor")
    plt.setp(ax.get_yticklabels(), rotation=45, ha="right",
                rotation_mode="anchor")

    plt.show()

def reporting_table(y_test,y_pred,le):
    report = classification_report(y_test, y_pred, target_names=le.classes_,output_dict=True,digits=2)
    df_report = pd.DataFrame(report).transpose().round(2)
    return df_report.style.background_gradient(axis=None, subset=pd.IndexSlice[le.classes_[0]:le.classes_[-1], :df_report.columns[-2]],cmap="OrRd").set_precision(2) 


metricas = {
  #'ks_stat' : make_scorer(ks_stat, needs_proba=True, greater_is_better=True),
  'precision' : make_scorer(precision, zero_division = 0, average='macro'),
  'recall': make_scorer(recall,average='macro'),
  'f1' : make_scorer(f1, average='macro'),
  'f05' : make_scorer(f05),
  'f2' : make_scorer(f2),
  'roc_auc' : make_scorer(roc_auc, needs_proba = True, multi_class='ovr'),
  'accuracy': make_scorer(accuracy),
  #'average_precision' : make_scorer(average_precision_score, average='macro'),
  #'brier_loss' : make_scorer(brier_score_loss, needs_proba = True, average='macro'),
  #'log_loss' : make_scorer(log_loss, needs_proba=True, average='macro')
}

# %% [markdown]
# # Parámetros

# %%
OPTIMIZAR = False
best_params = None

# %% [markdown]
# # Datos

# %%
df = pd.read_parquet('../../01_datos/01_criterios/criterio_random_10fr_with_face.parquet')

# Encoder
le = preprocessing.LabelEncoder()
le.fit(df['sign'])
df['target'] = le.transform(df['sign'])
df.drop('sign',axis=1, inplace=True)
df.head()
# Out:
#    fr_0_face_p0_x  fr_0_face_p0_y  fr_0_face_p1_x  fr_0_face_p1_y  \
# 0        0.496552        0.248379        0.499120        0.239927
# 1        0.492085        0.257791        0.494179        0.249480
# 2        0.494856        0.262691        0.497182        0.254657
# 3        0.493562        0.266458        0.495591        0.258068
# 4        0.495754        0.276606        0.498205        0.268949
#
#    fr_0_face_p2_x  fr_0_face_p2_y  fr_0_face_p3_x  fr_0_face_p3_y  \
# 0        0.503776        0.234988        0.510538        0.232742
# 1        0.498378        0.244569        0.504735        0.242141
# 2        0.501519        0.250010        0.507952        0.247802
# 3        0.499731        0.253193        0.506026        0.250872
# 4        0.502903        0.264623        0.509762        0.262571
#
#    fr_0_face_p4_x  fr_0_face_p4_y  ...  fr_9_right_hand_p16_y  \
# 0        0.518761        0.234497  ...               0.386130
# 1        0.512686        0.243489  ...               0.410465
# 2        0.515978        0.249399  ...               0.421466
# 3        0.513979        0.252280  ...               0.418498
# 4        0.518246        0.264129  ...               0.429658
#
#    fr_9_right_hand_p17_x  fr_9_right_hand_p17_y  fr_9_right_hand_p18_x  \
# 0               0.426423               0.490539               0.424275
# 1               0.433397               0.515740               0.422078
# 2               0.440995               0.525876               0.430971
# 3               0.455433               0.522799               0.444785
# 4               0.464094               0.530552               0.454496
#
#    fr_9_right_hand_p18_y  fr_9_right_hand_p19_x  fr_9_right_hand_p19_y  \
# 0               0.458936               0.423810               0.437550
# 1               0.489677               0.415374               0.471019
# 2               0.500801               0.425215               0.483139
# 3               0.498641               0.438589               0.481068
# 4               0.506470               0.448543               0.488854
#
#    fr_9_right_hand_p20_x  fr_9_right_hand_p20_y  target
# 0               0.423738               0.418148       3
# 1               0.410164               0.453710       3
# 2               0.420960               0.466409       3
# 3               0.433860               0.464379       3
# 4               0.443813               0.472008       3
#
# [5 rows x 2661 columns]

# %%
X = df.drop(['target'],axis=1)
y = df['target']

SEED = 42
TEST_SIZE = 0.2
VALID_SIZE = 0.2

X_train, X_test, y_train, y_test = train_test_split(
                                                    X,
                                                    y,
                                                    stratify=y, 
                                                    test_size=TEST_SIZE,
                                                    random_state=SEED, 
                                                    shuffle=True,
                                                )

X_train, X_valid, y_train, y_valid = train_test_split(
                                                    X_train,
                                                    y_train,
                                                    stratify=y_train, 
                                                    test_size=VALID_SIZE,
                                                    random_state=SEED, 
                                                    shuffle=True,
                                                )

print(f"{'{ Params modelo }':=^80}")
print(f"{'Proporción partición train: '+str(round(1 - TEST_SIZE - VALID_SIZE,2)):-<80}")
print(f"{'Proporción partición test: '+str(round(TEST_SIZE,2)):-<80}")
print(f"{'Proporción partición validacion: '+str(round(VALID_SIZE,2)):-<80}")
# Out:
# ==============================={ Params modelo }================================
# Proporción partición train: 0.6-------------------------------------------------
# Proporción partición test: 0.2--------------------------------------------------
# Proporción partición validacion: 0.2--------------------------------------------

# %% [markdown]
# # Modelado

# %%
# Definicion de modelo xgboost base
modelxgb_base = xgb.XGBClassifier(seed = SEED)
modelxgb_base.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %% [markdown]
# ## CrossValidate

# %%
# %%time
# Cross-validation
cv_metrics_xgb_ajuste, cv_mean_metrics_rl_ajuste= eval_model_cv(X=X_train, y=y_train, model=modelxgb_base, metricas_=metricas)
cv_metrics_xgb_ajuste
# Out:
# SCORES
# {'fit_time': array([14.01945448, 14.90641427, 16.57947397, 16.59881186, 16.36262059,
#        16.71957803, 16.55758548, 16.49287415, 16.60885954, 16.49957204,
#        16.89645839, 16.36593819, 16.51481009, 16.68239021, 16.31584907,
#        17.89983797, 17.75716233, 16.9639864 , 16.67508626, 16.48278713,
#        16.57522321, 16.59175777, 16.52857852, 16.72857714, 16.35879064,
#        16.50609398, 16.51467586, 16.59111476, 16.33525586, 16.53947163]), 'score_time': array([0.26338601, 0.26300192, 0.27399921, 0.27499557, 0.27700281,
#        0.27500439, 0.27808762, 0.27549815, 0.26600027, 0.27699995,
#        0.27499986, 0.26700139, 0.27999759, 0.28100061, 0.29999876,
#        0.34700298, 0.29400039, 0.27499962, 0.27899861, 0.27865052,
#        0.27100253, 0.2779994 , 0.27700138, 0.26995063, 0.27412963,
#        0.27179432, 0.27400017, 0.28099942, 0.27343082, 0.28299999]), 'test_precision': array([0.938322  , 0.86360544, 0.92834467, 0.91485261, 0.92256236,
#        0.95986395, 0.93560091, 0.89637188, 0.91632653, 0.8521542 ,
#        0.95147392, 0.88321995, 0.91564626, 0.92329932, 0.88185941,
#        0.93718821, 0.90079365, 0.96938776, 0.91337868, 0.91088435,
#        0.95068027, 0.90340136, 0.8946712 , 0.9478458 , 0.92414966,
#        0.87477324, 0.91088435, 0.96371882, 0.88049887, 0.93764172]), 'test_recall': array([0.93015873, 0.82539683, 0.92222222, 0.9       , 0.90952381,
#        0.95238095, 0.92698413, 0.88730159, 0.9047619 , 0.82698413,
#        0.94444444, 0.85714286, 0.9       , 0.91111111, 0.85714286,
#        0.92857143, 0.87936508, 0.95555556, 0.91111111, 0.9015873 ,
#        0.93809524, 0.9       , 0.88253968, 0.93650794, 0.92222222,
#        0.85873016, 0.9031746 , 0.95714286, 0.86825397, 0.92698413]), 'test_f1': array([0.92827543, 0.81201021, 0.92098272, 0.90060654, 0.90879834,
#        0.95266215, 0.92445887, 0.8829488 , 0.90226255, 0.82959633,
#        0.94476634, 0.85571783, 0.9012358 , 0.91068191, 0.85524238,
#        0.92879713, 0.88048592, 0.95663041, 0.90628631, 0.9008177 ,
#        0.93786742, 0.8957783 , 0.87814144, 0.93232958, 0.91865542,
#        0.85592741, 0.901998  , 0.95678396, 0.85383505, 0.92644763]), 'test_f05': array([0.93285886, 0.82755253, 0.92422318, 0.90729234, 0.91504803,
#        0.95609922, 0.92926563, 0.88828988, 0.90852756, 0.84020225,
#        0.94797739, 0.86817659, 0.90816192, 0.91675026, 0.86713903,
#        0.93279246, 0.88994804, 0.96269135, 0.90881652, 0.90560911,
#        0.94383522, 0.8987858 , 0.88423895, 0.93800308, 0.92082792,
#        0.86442659, 0.90612035, 0.96002734, 0.85947395, 0.93163985]), 'test_f2': array([0.92794991, 0.81538833, 0.92079854, 0.89872596, 0.90766862,
#        0.95169955, 0.92447185, 0.88366411, 0.90184623, 0.82599965,
#        0.94383951, 0.85339085, 0.89899001, 0.90923722, 0.8533414 ,
#        0.9277223 , 0.87777639, 0.95466745, 0.90795876, 0.89988398,
#        0.93653749, 0.89698685, 0.87899475, 0.93316141, 0.91972511,
#        0.85504515, 0.901466  , 0.95615125, 0.85981501, 0.92538997]), 'test_roc_auc': array([0.99774388, 0.99307728, 0.99433752, 0.99587892, 0.99520353,
#        0.99832299, 0.9991806 , 0.99741878, 0.99734545, 0.99421605,
#        0.99591979, 0.99163903, 0.99644124, 0.99459615, 0.99054309,
#        0.99904499, 0.99506792, 0.99940102, 0.99733131, 0.99669412,
#        0.99850101, 0.99634383, 0.9919966 , 0.99547055, 0.99356207,
#        0.99000064, 0.99832873, 0.99931621, 0.98953   , 0.99370188]), 'test_accuracy': array([0.92857143, 0.83035714, 0.91964286, 0.90178571, 0.91071429,
#        0.95535714, 0.92857143, 0.89285714, 0.90178571, 0.83035714,
#        0.94642857, 0.85714286, 0.90178571, 0.91071429, 0.85714286,
#        0.92857143, 0.88392857, 0.95535714, 0.91071429, 0.90178571,
#        0.9375    , 0.89285714, 0.88392857, 0.9375    , 0.91964286,
#        0.85714286, 0.90178571, 0.95535714, 0.86607143, 0.92857143])}
# EVAL_DF
#      fit_time  score_time  test_precision  test_recall   test_f1  test_f05  \
# 0   14.019454    0.263386        0.938322     0.930159  0.928275  0.932859
# 1   14.906414    0.263002        0.863605     0.825397  0.812010  0.827553
# 2   16.579474    0.273999        0.928345     0.922222  0.920983  0.924223
# 3   16.598812    0.274996        0.914853     0.900000  0.900607  0.907292
# 4   16.362621    0.277003        0.922562     0.909524  0.908798  0.915048
# 5   16.719578    0.275004        0.959864     0.952381  0.952662  0.956099
# 6   16.557585    0.278088        0.935601     0.926984  0.924459  0.929266
# 7   16.492874    0.275498        0.896372     0.887302  0.882949  0.888290
# 8   16.608860    0.266000        0.916327     0.904762  0.902263  0.908528
# 9   16.499572    0.277000        0.852154     0.826984  0.829596  0.840202
# 10  16.896458    0.275000        0.951474     0.944444  0.944766  0.947977
# 11  16.365938    0.267001        0.883220     0.857143  0.855718  0.868177
# 12  16.514810    0.279998        0.915646     0.900000  0.901236  0.908162
# 13  16.682390    0.281001        0.923299     0.911111  0.910682  0.916750
# 14  16.315849    0.299999        0.881859     0.857143  0.855242  0.867139
# 15  17.899838    0.347003        0.937188     0.928571  0.928797  0.932792
# 16  17.757162    0.294000        0.900794     0.879365  0.880486  0.889948
# 17  16.963986    0.275000        0.969388     0.955556  0.956630  0.962691
# 18  16.675086    0.278999        0.913379     0.911111  0.906286  0.908817
# 19  16.482787    0.278651        0.910884     0.901587  0.900818  0.905609
# 20  16.575223    0.271003        0.950680     0.938095  0.937867  0.943835
# 21  16.591758    0.277999        0.903401     0.900000  0.895778  0.898786
# 22  16.528579    0.277001        0.894671     0.882540  0.878141  0.884239
# 23  16.728577    0.269951        0.947846     0.936508  0.932330  0.938003
# 24  16.358791    0.274130        0.924150     0.922222  0.918655  0.920828
# 25  16.506094    0.271794        0.874773     0.858730  0.855927  0.864427
# 26  16.514676    0.274000        0.910884     0.903175  0.901998  0.906120
# 27  16.591115    0.280999        0.963719     0.957143  0.956784  0.960027
# 28  16.335256    0.273431        0.880499     0.868254  0.853835  0.859474
# 29  16.539472    0.283000        0.937642     0.926984  0.926448  0.931640
#
#      test_f2  test_roc_auc  test_accuracy
# 0   0.927950      0.997744       0.928571
# 1   0.815388      0.993077       0.830357
# 2   0.920799      0.994338       0.919643
# 3   0.898726      0.995879       0.901786
# 4   0.907669      0.995204       0.910714
# 5   0.951700      0.998323       0.955357
# 6   0.924472      0.999181       0.928571
# 7   0.883664      0.997419       0.892857
# 8   0.901846      0.997345       0.901786
# 9   0.826000      0.994216       0.830357
# 10  0.943840      0.995920       0.946429
# 11  0.853391      0.991639       0.857143
# 12  0.898990      0.996441       0.901786
# 13  0.909237      0.994596       0.910714
# 14  0.853341      0.990543       0.857143
# 15  0.927722      0.999045       0.928571
# 16  0.877776      0.995068       0.883929
# 17  0.954667      0.999401       0.955357
# 18  0.907959      0.997331       0.910714
# 19  0.899884      0.996694       0.901786
# 20  0.936537      0.998501       0.937500
# 21  0.896987      0.996344       0.892857
# 22  0.878995      0.991997       0.883929
# 23  0.933161      0.995471       0.937500
# 24  0.919725      0.993562       0.919643
# 25  0.855045      0.990001       0.857143
# 26  0.901466      0.998329       0.901786
# 27  0.956151      0.999316       0.955357
# 28  0.859815      0.989530       0.866071
# 29  0.925390      0.993702       0.928571
# DICC
# {'precision': 0.92, 'recall': 0.9, 'f1': 0.9, 'f05': 0.91, 'f2': 0.9, 'roc_auc': 1.0, 'accuracy': 0.9}
# TABLA
#                mean       std       min       25%       50%       75%  \
# precision  0.916780  0.029905  0.852154  0.897477  0.915986  0.937528
# recall     0.904180  0.035256  0.825397  0.883730  0.907143  0.928175
# f1         0.902034  0.036871  0.812010  0.881102  0.904274  0.927818
# f05        0.908160  0.034513  0.827553  0.888704  0.908672  0.932504
# f2         0.901610  0.036557  0.815388  0.880162  0.904757  0.927139
# roc_auc    0.995539  0.002842  0.989530  0.993830  0.995899  0.997663
# accuracy   0.904464  0.034711  0.830357  0.886161  0.906250  0.928571
#
#                 max
# precision  0.969388
# recall     0.957143
# f1         0.956784
# f05        0.962691
# f2         0.956151
# roc_auc    0.999401
# accuracy   0.955357
# CPU times: total: 1h 52s
# Wall time: 8min 23s
# <style type="text/css">
# </style>
# <table id="T_91ac7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91ac7_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_91ac7_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_91ac7_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_91ac7_level0_col3" class="col_heading level0 col3" >25%</th>
#       <th id="T_91ac7_level0_col4" class="col_heading level0 col4" >50%</th>
#       <th id="T_91ac7_level0_col5" class="col_heading level0 col5" >75%</th>
#       <th id="T_91ac7_level0_col6" class="col_heading level0 col6" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91ac7_level0_row0" class="row_heading level0 row0" >precision</th>
#       <td id="T_91ac7_row0_col0" class="data row0 col0" >0.92</td>
#       <td id="T_91ac7_row0_col1" class="data row0 col1" >0.03</td>
#       <td id="T_91ac7_row0_col2" class="data row0 col2" >0.85</td>
#       <td id="T_91ac7_row0_col3" class="data row0 col3" >0.90</td>
#       <td id="T_91ac7_row0_col4" class="data row0 col4" >0.92</td>
#       <td id="T_91ac7_row0_col5" class="data row0 col5" >0.94</td>
#       <td id="T_91ac7_row0_col6" class="data row0 col6" >0.97</td>
#     </tr>
#     <tr>
#       <th id="T_91ac7_level0_row1" class="row_heading level0 row1" >recall</th>
#       <td id="T_91ac7_row1_col0" class="data row1 col0" >0.90</td>
#       <td id="T_91ac7_row1_col1" class="data row1 col1" >0.04</td>
#       <td id="T_91ac7_row1_col2" class="data row1 col2" >0.83</td>
#       <td id="T_91ac7_row1_col3" class="data row1 col3" >0.88</td>
#       <td id="T_91ac7_row1_col4" class="data row1 col4" >0.91</td>
#       <td id="T_91ac7_row1_col5" class="data row1 col5" >0.93</td>
#       <td id="T_91ac7_row1_col6" class="data row1 col6" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_91ac7_level0_row2" class="row_heading level0 row2" >f1</th>
#       <td id="T_91ac7_row2_col0" class="data row2 col0" >0.90</td>
#       <td id="T_91ac7_row2_col1" class="data row2 col1" >0.04</td>
#       <td id="T_91ac7_row2_col2" class="data row2 col2" >0.81</td>
#       <td id="T_91ac7_row2_col3" class="data row2 col3" >0.88</td>
#       <td id="T_91ac7_row2_col4" class="data row2 col4" >0.90</td>
#       <td id="T_91ac7_row2_col5" class="data row2 col5" >0.93</td>
#       <td id="T_91ac7_row2_col6" class="data row2 col6" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_91ac7_level0_row3" class="row_heading level0 row3" >f05</th>
#       <td id="T_91ac7_row3_col0" class="data row3 col0" >0.91</td>
#       <td id="T_91ac7_row3_col1" class="data row3 col1" >0.03</td>
#       <td id="T_91ac7_row3_col2" class="data row3 col2" >0.83</td>
#       <td id="T_91ac7_row3_col3" class="data row3 col3" >0.89</td>
#       <td id="T_91ac7_row3_col4" class="data row3 col4" >0.91</td>
#       <td id="T_91ac7_row3_col5" class="data row3 col5" >0.93</td>
#       <td id="T_91ac7_row3_col6" class="data row3 col6" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_91ac7_level0_row4" class="row_heading level0 row4" >f2</th>
#       <td id="T_91ac7_row4_col0" class="data row4 col0" >0.90</td>
#       <td id="T_91ac7_row4_col1" class="data row4 col1" >0.04</td>
#       <td id="T_91ac7_row4_col2" class="data row4 col2" >0.82</td>
#       <td id="T_91ac7_row4_col3" class="data row4 col3" >0.88</td>
#       <td id="T_91ac7_row4_col4" class="data row4 col4" >0.90</td>
#       <td id="T_91ac7_row4_col5" class="data row4 col5" >0.93</td>
#       <td id="T_91ac7_row4_col6" class="data row4 col6" >0.96</td>
#     </tr>
#     <tr>
#       <th id="T_91ac7_level0_row5" class="row_heading level0 row5" >roc_auc</th>
#       <td id="T_91ac7_row5_col0" class="data row5 col0" >1.00</td>
#       <td id="T_91ac7_row5_col1" class="data row5 col1" >0.00</td>
#       <td id="T_91ac7_row5_col2" class="data row5 col2" >0.99</td>
#       <td id="T_91ac7_row5_col3" class="data row5 col3" >0.99</td>
#       <td id="T_91ac7_row5_col4" class="data row5 col4" >1.00</td>
#       <td id="T_91ac7_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_91ac7_row5_col6" class="data row5 col6" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_91ac7_level0_row6" class="row_heading level0 row6" >accuracy</th>
#       <td id="T_91ac7_row6_col0" class="data row6 col0" >0.90</td>
#       <td id="T_91ac7_row6_col1" class="data row6 col1" >0.03</td>
#       <td id="T_91ac7_row6_col2" class="data row6 col2" >0.83</td>
#       <td id="T_91ac7_row6_col3" class="data row6 col3" >0.89</td>
#       <td id="T_91ac7_row6_col4" class="data row6 col4" >0.91</td>
#       <td id="T_91ac7_row6_col5" class="data row6 col5" >0.93</td>
#       <td id="T_91ac7_row6_col6" class="data row6 col6" >0.96</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Un desviación estándar (std) de 0.03 en el resultado de la función cross_validate indica que los resultados de la métrica de evaluación utilizada tienen una variabilidad relativamente baja entre las diferentes divisiones de entrenamiento y prueba durante la validación cruzada.
#
# Esto indica qué tan dispersos están los valores con respecto a la media. En el contexto de la validación cruzada, una desviación estándar baja indica que los resultados de la métrica de evaluación (por ejemplo, precisión, exactitud, puntaje F1, etc.) son consistentes y similares en todas las divisiones de entrenamiento y prueba. Por lo tanto este valor sugiere que el modelo tiene un rendimiento estable y robusto en diferentes conjuntos de datos de entrenamiento y prueba. Esto es deseable, ya que indica que el modelo es menos sensible a la variación en los datos de prueba y es más confiable en términos de su rendimiento general.

# %% [markdown]
# ## Métricas de test - modelo base

# %%
# %%time
# Entrenamiento de modelo base y evaluacion con datos de test
test_xgb, test_dicc_xgb= metrics(y_test, X_test, modelxgb_base)
test_xgb
# Out:
# CPU times: total: 922 ms
# Wall time: 248 ms
#      metrica  valor
# 0  precision   0.89
# 1     recall   0.88
# 2         f1   0.88
# 3        f05   0.89
# 4         f2   0.88
# 5   accuracy   0.88

# %% [markdown]
# ## Evaluacion de métricas test

# %%
plot_matrix_confusion(X_test,y_test,le,modelxgb_base)

# %%
y_pred = modelxgb_base.predict(X_test)
reporting_table(y_test,y_pred,le)
# Out:
# C:\Users\facur\AppData\Local\Temp\ipykernel_8248\3401407969.py:119: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   return df_report.style.background_gradient(axis=None, subset=pd.IndexSlice[le.classes_[0]:le.classes_[-1], :df_report.columns[-2]],cmap="OrRd").set_precision(2)
# <style type="text/css">
# #T_65a74_row0_col0, #T_65a74_row0_col1, #T_65a74_row0_col2, #T_65a74_row2_col0, #T_65a74_row2_col1, #T_65a74_row2_col2, #T_65a74_row3_col0, #T_65a74_row3_col1, #T_65a74_row3_col2, #T_65a74_row6_col1, #T_65a74_row11_col0, #T_65a74_row11_col1, #T_65a74_row11_col2, #T_65a74_row14_col1, #T_65a74_row17_col0, #T_65a74_row17_col1, #T_65a74_row17_col2, #T_65a74_row19_col1 {
#   background-color: #d62f1e;
#   color: #f1f1f1;
# }
# #T_65a74_row1_col0, #T_65a74_row1_col1, #T_65a74_row1_col2, #T_65a74_row4_col0, #T_65a74_row4_col1, #T_65a74_row4_col2, #T_65a74_row9_col0, #T_65a74_row10_col1, #T_65a74_row12_col1, #T_65a74_row13_col1, #T_65a74_row15_col1, #T_65a74_row16_col0, #T_65a74_row16_col1, #T_65a74_row16_col2, #T_65a74_row19_col0, #T_65a74_row20_col0 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_65a74_row5_col0 {
#   background-color: #fdc58e;
#   color: #000000;
# }
# #T_65a74_row5_col1, #T_65a74_row8_col1, #T_65a74_row13_col2, #T_65a74_row18_col1 {
#   background-color: #fc8c59;
#   color: #f1f1f1;
# }
# #T_65a74_row5_col2 {
#   background-color: #fdb27b;
#   color: #000000;
# }
# #T_65a74_row6_col0, #T_65a74_row14_col0 {
#   background-color: #f77d52;
#   color: #f1f1f1;
# }
# #T_65a74_row6_col2, #T_65a74_row14_col2 {
#   background-color: #ea5a3f;
#   color: #f1f1f1;
# }
# #T_65a74_row7_col0 {
#   background-color: #e0442f;
#   color: #f1f1f1;
# }
# #T_65a74_row7_col1 {
#   background-color: #fdd49f;
#   color: #000000;
# }
# #T_65a74_row7_col2 {
#   background-color: #fc9f6a;
#   color: #000000;
# }
# #T_65a74_row8_col0, #T_65a74_row18_col0 {
#   background-color: #dc3a27;
#   color: #f1f1f1;
# }
# #T_65a74_row8_col2, #T_65a74_row18_col2 {
#   background-color: #f26d4b;
#   color: #f1f1f1;
# }
# #T_65a74_row9_col1, #T_65a74_row20_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_65a74_row9_col2, #T_65a74_row20_col2 {
#   background-color: #fdba83;
#   color: #000000;
# }
# #T_65a74_row10_col0, #T_65a74_row12_col2, #T_65a74_row15_col2 {
#   background-color: #cf2618;
#   color: #f1f1f1;
# }
# #T_65a74_row10_col2, #T_65a74_row19_col2 {
#   background-color: #b30000;
#   color: #f1f1f1;
# }
# #T_65a74_row12_col0, #T_65a74_row15_col0 {
#   background-color: #f4754f;
#   color: #f1f1f1;
# }
# #T_65a74_row13_col0 {
#   background-color: #fee0b8;
#   color: #000000;
# }
# </style>
# <table id="T_65a74">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_65a74_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_65a74_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_65a74_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_65a74_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65a74_level0_row0" class="row_heading level0 row0" >Uruguay</th>
#       <td id="T_65a74_row0_col0" class="data row0 col0" >0.90</td>
#       <td id="T_65a74_row0_col1" class="data row0 col1" >0.90</td>
#       <td id="T_65a74_row0_col2" class="data row0 col2" >0.90</td>
#       <td id="T_65a74_row0_col3" class="data row0 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row1" class="row_heading level0 row1" >amargo</th>
#       <td id="T_65a74_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_65a74_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_65a74_row1_col2" class="data row1 col2" >1.00</td>
#       <td id="T_65a74_row1_col3" class="data row1 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row2" class="row_heading level0 row2" >aprender</th>
#       <td id="T_65a74_row2_col0" class="data row2 col0" >0.90</td>
#       <td id="T_65a74_row2_col1" class="data row2 col1" >0.90</td>
#       <td id="T_65a74_row2_col2" class="data row2 col2" >0.90</td>
#       <td id="T_65a74_row2_col3" class="data row2 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row3" class="row_heading level0 row3" >brillante</th>
#       <td id="T_65a74_row3_col0" class="data row3 col0" >0.90</td>
#       <td id="T_65a74_row3_col1" class="data row3 col1" >0.90</td>
#       <td id="T_65a74_row3_col2" class="data row3 col2" >0.90</td>
#       <td id="T_65a74_row3_col3" class="data row3 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row4" class="row_heading level0 row4" >comida</th>
#       <td id="T_65a74_row4_col0" class="data row4 col0" >1.00</td>
#       <td id="T_65a74_row4_col1" class="data row4 col1" >1.00</td>
#       <td id="T_65a74_row4_col2" class="data row4 col2" >1.00</td>
#       <td id="T_65a74_row4_col3" class="data row4 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row5" class="row_heading level0 row5" >comprar</th>
#       <td id="T_65a74_row5_col0" class="data row5 col0" >0.73</td>
#       <td id="T_65a74_row5_col1" class="data row5 col1" >0.80</td>
#       <td id="T_65a74_row5_col2" class="data row5 col2" >0.76</td>
#       <td id="T_65a74_row5_col3" class="data row5 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row6" class="row_heading level0 row6" >donde</th>
#       <td id="T_65a74_row6_col0" class="data row6 col0" >0.82</td>
#       <td id="T_65a74_row6_col1" class="data row6 col1" >0.90</td>
#       <td id="T_65a74_row6_col2" class="data row6 col2" >0.86</td>
#       <td id="T_65a74_row6_col3" class="data row6 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row7" class="row_heading level0 row7" >encontrar</th>
#       <td id="T_65a74_row7_col0" class="data row7 col0" >0.88</td>
#       <td id="T_65a74_row7_col1" class="data row7 col1" >0.70</td>
#       <td id="T_65a74_row7_col2" class="data row7 col2" >0.78</td>
#       <td id="T_65a74_row7_col3" class="data row7 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row8" class="row_heading level0 row8" >espumadera</th>
#       <td id="T_65a74_row8_col0" class="data row8 col0" >0.89</td>
#       <td id="T_65a74_row8_col1" class="data row8 col1" >0.80</td>
#       <td id="T_65a74_row8_col2" class="data row8 col2" >0.84</td>
#       <td id="T_65a74_row8_col3" class="data row8 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row9" class="row_heading level0 row9" >hijo</th>
#       <td id="T_65a74_row9_col0" class="data row9 col0" >1.00</td>
#       <td id="T_65a74_row9_col1" class="data row9 col1" >0.60</td>
#       <td id="T_65a74_row9_col2" class="data row9 col2" >0.75</td>
#       <td id="T_65a74_row9_col3" class="data row9 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row10" class="row_heading level0 row10" >hombre</th>
#       <td id="T_65a74_row10_col0" class="data row10 col0" >0.91</td>
#       <td id="T_65a74_row10_col1" class="data row10 col1" >1.00</td>
#       <td id="T_65a74_row10_col2" class="data row10 col2" >0.95</td>
#       <td id="T_65a74_row10_col3" class="data row10 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row11" class="row_heading level0 row11" >leche</th>
#       <td id="T_65a74_row11_col0" class="data row11 col0" >0.90</td>
#       <td id="T_65a74_row11_col1" class="data row11 col1" >0.90</td>
#       <td id="T_65a74_row11_col2" class="data row11 col2" >0.90</td>
#       <td id="T_65a74_row11_col3" class="data row11 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row12" class="row_heading level0 row12" >lejos</th>
#       <td id="T_65a74_row12_col0" class="data row12 col0" >0.83</td>
#       <td id="T_65a74_row12_col1" class="data row12 col1" >1.00</td>
#       <td id="T_65a74_row12_col2" class="data row12 col2" >0.91</td>
#       <td id="T_65a74_row12_col3" class="data row12 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row13" class="row_heading level0 row13" >mujer</th>
#       <td id="T_65a74_row13_col0" class="data row13 col0" >0.67</td>
#       <td id="T_65a74_row13_col1" class="data row13 col1" >1.00</td>
#       <td id="T_65a74_row13_col2" class="data row13 col2" >0.80</td>
#       <td id="T_65a74_row13_col3" class="data row13 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_65a74_level0_row14" class="row_heading level0 row14" >nacer</th>
#       <td id="T_65a74_row14_col0" class="da

# %% [markdown]
# >Precision
#
# La precisión representa la proporción de instancias clasificadas como positivas que son realmente positivas. Por ejemplo, si la precisión para la clase "Uruguay" es 0.77, significa que el 77% de las instancias clasificadas como "Uruguay" son realmente "Uruguay". Una precisión alta indica que el modelo tiene una baja tasa de falsos positivos.
#
# >Recall
#
# El recall representa la proporción de instancias positivas que fueron correctamente identificadas por el modelo. Por ejemplo, si el recall para la clase "Uruguay" es 1, significa que el modelo identificó correctamente todas las instancias de la clase "Uruguay". Un recall alto indica que el modelo tiene una baja tasa de falsos negativos.
#
# >F1-score
#
# El F1-score es una medida combinada de precision y recall que proporciona una medida única del rendimiento del modelo. Es la media armónica de precision y recall. Un F1-score más alto indica un mejor equilibrio entre precision y recall, lo que implica un mejor rendimiento del modelo en general.
#
# >Support
#
# El support es el número de instancias en cada clase. En tu caso, parece que cada clase tiene un total de 10 instancias. Esta información es útil para comprender la distribución de las clases y el tamaño de cada una.
#
# > Accuracy
#
# La exactitud representa la proporción de instancias clasificadas correctamente sobre el total de instancias. Por ejemplo, si la exactitud es del 88%, significa que el modelo clasificó correctamente el 88% de las instancias. Una alta exactitud indica que el modelo está realizando buenas predicciones en general.
#
# > Macro Avg
#
# El macro avg es el promedio no ponderado de las métricas (precision, recall, F1-score) para todas las clases. Proporciona una medida general del rendimiento del modelo sin tener en cuenta el desequilibrio de clases. Un macro avg alto indica un buen rendimiento promedio en todas las clases.
#
# >Weighted Avg
#
# El weighted avg es el promedio ponderado de las métricas (precision, recall, F1-score) para todas las clases, donde el peso es proporcional al número de instancias en cada clase. Toma en cuenta el desequilibrio de clases al calcular la medida general del rendimiento del modelo. Un weighted avg alto indica un buen rendimiento general del modelo considerando el tamaño y la distribución de las clases.

# %% [markdown]
# # Optimización

# %%
# %%time
if OPTIMIZAR:
    param_grid = {
        'learning_rate': [0.01, 0.05, 0.1, 0.2],
        'n_estimators': [100, 200, 300, 400, 500],
        'max_depth': [3, 4, 5, 6],
        'min_child_weight': [1, 2, 3, 4],
        'subsample': [0.6, 0.7, 0.8, 0.9, 1.0],
        'colsample_bytree': [0.6, 0.7, 0.8, 0.9, 1.0],
        'reg_alpha': [0.0, 0.1, 0.5, 1.0],
        'reg_lambda': [0.0, 0.1, 0.5, 1.0]
    }


    # Realizar la búsqueda aleatoria
    random_search = RandomizedSearchCV(model, param_distributions=param_grid, n_iter=10, cv=5, n_jobs=-1)
    random_search.fit(X, y)

    # Imprimir los mejores hiperparámetros encontrados
    print("Mejores hiperparámetros encontrados:")
    print(random_search.best_params_)
    best_params = random_search.best_params_
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %% [markdown]
# > learning_rate
#
# Tasa de aprendizaje que controla la contribución de cada árbol. Un valor más bajo puede hacer que el modelo sea más preciso, pero también puede requerir más árboles y tiempo de entrenamiento.
#
# > n_estimators
#
# Número de árboles en el modelo. Un valor más alto puede mejorar el rendimiento, pero también aumentará el tiempo de entrenamiento.
#
# > max_depth
#
# Profundidad máxima de cada árbol. Controla la complejidad del modelo. Un valor más alto puede capturar relaciones más complejas, pero también puede provocar sobreajuste.
#
# > min_child_weight
#
# Peso mínimo necesario para crear un nuevo nodo en el árbol. Controla la regularización y ayuda a evitar divisiones insignificantes. Un valor más alto puede evitar sobreajuste.
#
# > subsample
#
# Proporción de muestras utilizadas para entrenar cada árbol. Un valor menor reduce la varianza y puede evitar el sobreajuste.
#
# > colsample_bytree
#
# Proporción de características utilizadas para entrenar cada árbol. Un valor menor reduce la varianza y puede evitar el sobreajuste.
#
# > reg_alpha
#
# Término de regularización L1 (Lasso) aplicado a los pesos de los nodos del árbol. Un valor más alto impone una mayor regularización.
#
# > reg_lambda
#
# Término de regularización L2 (Ridge) aplicado a los pesos de los nodos del árbol. Un valor más alto impone una mayor regularización.

# %% [markdown]
# ## Probamos mejores hiperparametros

# %%
if not best_params:
    best_params = {'subsample': 0.7, 'reg_lambda': 0.0, 'reg_alpha': 0.1, 'n_estimators': 400, 'min_child_weight': 4, 'max_depth': 5, 'learning_rate': 0.2, 'colsample_bytree': 0.7}

modelxgb_opt = xgb.XGBClassifier(**best_params)
modelxgb_opt.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.7, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=4, missing=nan, monotone_constraints=None,
#               n_estimators=400, n_jobs=None, num_parallel_tree=None,
#               objective='multi:softprob', predictor=None, ...)

# %%
test_xgb, test_dicc_xgb= metrics(y_test, X_test, modelxgb_opt)
test_xgb
# Out:
#      metrica  valor
# 0  precision   0.92
# 1     recall   0.91
# 2         f1   0.91
# 3        f05   0.92
# 4         f2   0.91
# 5   accuracy   0.91

# %%
plot_matrix_confusion(X_test,y_test,le,modelxgb_opt)

# %%
y_pred = modelxgb_opt.predict(X_test)
reporting_table(y_test,y_pred,le)
# Out:
# C:\Users\facur\AppData\Local\Temp\ipykernel_8248\3401407969.py:119: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   return df_report.style.background_gradient(axis=None, subset=pd.IndexSlice[le.classes_[0]:le.classes_[-1], :df_report.columns[-2]],cmap="OrRd").set_precision(2)
# <style type="text/css">
# #T_bccc7_row0_col0, #T_bccc7_row0_col1, #T_bccc7_row0_col2, #T_bccc7_row1_col0, #T_bccc7_row1_col1, #T_bccc7_row1_col2, #T_bccc7_row3_col0, #T_bccc7_row4_col0, #T_bccc7_row4_col1, #T_bccc7_row4_col2, #T_bccc7_row7_col0, #T_bccc7_row9_col0, #T_bccc7_row10_col1, #T_bccc7_row12_col0, #T_bccc7_row12_col1, #T_bccc7_row12_col2, #T_bccc7_row13_col1, #T_bccc7_row14_col0, #T_bccc7_row15_col0, #T_bccc7_row15_col1, #T_bccc7_row15_col2, #T_bccc7_row16_col0, #T_bccc7_row16_col1, #T_bccc7_row16_col2, #T_bccc7_row17_col1, #T_bccc7_row19_col0, #T_bccc7_row19_col1, #T_bccc7_row19_col2 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_bccc7_row2_col0, #T_bccc7_row2_col1, #T_bccc7_row2_col2, #T_bccc7_row6_col1, #T_bccc7_row8_col1, #T_bccc7_row11_col0, #T_bccc7_row11_col1, #T_bccc7_row11_col2, #T_bccc7_row20_col1 {
#   background-color: #d62f1e;
#   color: #f1f1f1;
# }
# #T_bccc7_row3_col1, #T_bccc7_row5_col1, #T_bccc7_row7_col1, #T_bccc7_row13_col2, #T_bccc7_row14_col1, #T_bccc7_row18_col1 {
#   background-color: #fc8c59;
#   color: #f1f1f1;
# }
# #T_bccc7_row3_col2, #T_bccc7_row5_col0, #T_bccc7_row7_col2, #T_bccc7_row14_col2, #T_bccc7_row18_col0 {
#   background-color: #dc3a27;
#   color: #f1f1f1;
# }
# #T_bccc7_row5_col2, #T_bccc7_row18_col2 {
#   background-color: #f26d4b;
#   color: #f1f1f1;
# }
# #T_bccc7_row6_col0, #T_bccc7_row8_col0, #T_bccc7_row20_col0 {
#   background-color: #f77d52;
#   color: #f1f1f1;
# }
# #T_bccc7_row6_col2, #T_bccc7_row8_col2, #T_bccc7_row20_col2 {
#   background-color: #ea5a3f;
#   color: #f1f1f1;
# }
# #T_bccc7_row9_col1 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_bccc7_row9_col2 {
#   background-color: #fdba83;
#   color: #000000;
# }
# #T_bccc7_row10_col0 {
#   background-color: #fda973;
#   color: #000000;
# }
# #T_bccc7_row10_col2 {
#   background-color: #e55038;
#   color: #f1f1f1;
# }
# #T_bccc7_row13_col0 {
#   background-color: #fee0b8;
#   color: #000000;
# }
# #T_bccc7_row17_col0 {
#   background-color: #cf2618;
#   color: #f1f1f1;
# }
# #T_bccc7_row17_col2 {
#   background-color: #b30000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bccc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bccc7_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_bccc7_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_bccc7_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_bccc7_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bccc7_level0_row0" class="row_heading level0 row0" >Uruguay</th>
#       <td id="T_bccc7_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_bccc7_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_bccc7_row0_col2" class="data row0 col2" >1.00</td>
#       <td id="T_bccc7_row0_col3" class="data row0 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row1" class="row_heading level0 row1" >amargo</th>
#       <td id="T_bccc7_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_bccc7_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_bccc7_row1_col2" class="data row1 col2" >1.00</td>
#       <td id="T_bccc7_row1_col3" class="data row1 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row2" class="row_heading level0 row2" >aprender</th>
#       <td id="T_bccc7_row2_col0" class="data row2 col0" >0.90</td>
#       <td id="T_bccc7_row2_col1" class="data row2 col1" >0.90</td>
#       <td id="T_bccc7_row2_col2" class="data row2 col2" >0.90</td>
#       <td id="T_bccc7_row2_col3" class="data row2 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row3" class="row_heading level0 row3" >brillante</th>
#       <td id="T_bccc7_row3_col0" class="data row3 col0" >1.00</td>
#       <td id="T_bccc7_row3_col1" class="data row3 col1" >0.80</td>
#       <td id="T_bccc7_row3_col2" class="data row3 col2" >0.89</td>
#       <td id="T_bccc7_row3_col3" class="data row3 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row4" class="row_heading level0 row4" >comida</th>
#       <td id="T_bccc7_row4_col0" class="data row4 col0" >1.00</td>
#       <td id="T_bccc7_row4_col1" class="data row4 col1" >1.00</td>
#       <td id="T_bccc7_row4_col2" class="data row4 col2" >1.00</td>
#       <td id="T_bccc7_row4_col3" class="data row4 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row5" class="row_heading level0 row5" >comprar</th>
#       <td id="T_bccc7_row5_col0" class="data row5 col0" >0.89</td>
#       <td id="T_bccc7_row5_col1" class="data row5 col1" >0.80</td>
#       <td id="T_bccc7_row5_col2" class="data row5 col2" >0.84</td>
#       <td id="T_bccc7_row5_col3" class="data row5 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row6" class="row_heading level0 row6" >donde</th>
#       <td id="T_bccc7_row6_col0" class="data row6 col0" >0.82</td>
#       <td id="T_bccc7_row6_col1" class="data row6 col1" >0.90</td>
#       <td id="T_bccc7_row6_col2" class="data row6 col2" >0.86</td>
#       <td id="T_bccc7_row6_col3" class="data row6 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row7" class="row_heading level0 row7" >encontrar</th>
#       <td id="T_bccc7_row7_col0" class="data row7 col0" >1.00</td>
#       <td id="T_bccc7_row7_col1" class="data row7 col1" >0.80</td>
#       <td id="T_bccc7_row7_col2" class="data row7 col2" >0.89</td>
#       <td id="T_bccc7_row7_col3" class="data row7 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row8" class="row_heading level0 row8" >espumadera</th>
#       <td id="T_bccc7_row8_col0" class="data row8 col0" >0.82</td>
#       <td id="T_bccc7_row8_col1" class="data row8 col1" >0.90</td>
#       <td id="T_bccc7_row8_col2" class="data row8 col2" >0.86</td>
#       <td id="T_bccc7_row8_col3" class="data row8 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row9" class="row_heading level0 row9" >hijo</th>
#       <td id="T_bccc7_row9_col0" class="data row9 col0" >1.00</td>
#       <td id="T_bccc7_row9_col1" class="data row9 col1" >0.60</td>
#       <td id="T_bccc7_row9_col2" class="data row9 col2" >0.75</td>
#       <td id="T_bccc7_row9_col3" class="data row9 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row10" class="row_heading level0 row10" >hombre</th>
#       <td id="T_bccc7_row10_col0" class="data row10 col0" >0.77</td>
#       <td id="T_bccc7_row10_col1" class="data row10 col1" >1.00</td>
#       <td id="T_bccc7_row10_col2" class="data row10 col2" >0.87</td>
#       <td id="T_bccc7_row10_col3" class="data row10 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row11" class="row_heading level0 row11" >leche</th>
#       <td id="T_bccc7_row11_col0" class="data row11 col0" >0.90</td>
#       <td id="T_bccc7_row11_col1" class="data row11 col1" >0.90</td>
#       <td id="T_bccc7_row11_col2" class="data row11 col2" >0.90</td>
#       <td id="T_bccc7_row11_col3" class="data row11 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row12" class="row_heading level0 row12" >lejos</th>
#       <td id="T_bccc7_row12_col0" class="data row12 col0" >1.00</td>
#       <td id="T_bccc7_row12_col1" class="data row12 col1" >1.00</td>
#       <td id="T_bccc7_row12_col2" class="data row12 col2" >1.00</td>
#       <td id="T_bccc7_row12_col3" class="data row12 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row13" class="row_heading level0 row13" >mujer</th>
#       <td id="T_bccc7_row13_col0" class="data row13 col0" >0.67</td>
#       <td id="T_bccc7_row13_col1" class="data row13 col1" >1.00</td>
#       <td id="T_bccc7_row13_col2" class="data row13 col2" >0.80</td>
#       <td id="T_bccc7_row13_col3" class="data row13 col3" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_bccc7_level0_row14" class="row_heading level0 row14" >nacer</th>
#       <td id="T_bccc7_row14_col0" class="data row14 col0" >1.00</td>
#       <td id="T_bccc7_row14_col1" class="data row14 col1" >0.80</td>
#       <td id="T_bccc7_row14_col2" class="data row14 col2" >0.89</td>
#       <td id="T_bccc7_row14_col3" cl

# %% [markdown]
# # Modelo final prueba con partición de validación

# %%
test_xgb, test_dicc_xgb= metrics(y_valid, X_valid, modelxgb_opt)
test_xgb
# Out:
#      metrica  valor
# 0  precision   0.93
# 1     recall   0.92
# 2         f1   0.92
# 3        f05   0.92
# 4         f2   0.92
# 5   accuracy   0.92

# %%
plot_matrix_confusion(X_valid,y_valid,le,modelxgb_opt)

# %%
y_pred = modelxgb_opt.predict(X_valid)
reporting_table(y_valid,y_pred,le)
# Out:
# C:\Users\facur\AppData\Local\Temp\ipykernel_8248\3401407969.py:119: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   return df_report.style.background_gradient(axis=None, subset=pd.IndexSlice[le.classes_[0]:le.classes_[-1], :df_report.columns[-2]],cmap="OrRd").set_precision(2)
# <style type="text/css">
# #T_d9495_row0_col0, #T_d9495_row0_col1, #T_d9495_row0_col2, #T_d9495_row1_col1, #T_d9495_row2_col0, #T_d9495_row4_col0, #T_d9495_row5_col0, #T_d9495_row7_col0, #T_d9495_row7_col1, #T_d9495_row7_col2, #T_d9495_row8_col0, #T_d9495_row9_col1, #T_d9495_row10_col0, #T_d9495_row10_col1, #T_d9495_row10_col2, #T_d9495_row11_col0, #T_d9495_row11_col1, #T_d9495_row11_col2, #T_d9495_row12_col1, #T_d9495_row13_col0, #T_d9495_row13_col1, #T_d9495_row13_col2, #T_d9495_row14_col0, #T_d9495_row14_col1, #T_d9495_row14_col2, #T_d9495_row16_col0, #T_d9495_row17_col0, #T_d9495_row18_col1, #T_d9495_row20_col1 {
#   background-color: #7f0000;
#   color: #f1f1f1;
# }
# #T_d9495_row1_col0, #T_d9495_row9_col0, #T_d9495_row12_col2, #T_d9495_row18_col0, #T_d9495_row20_col2 {
#   background-color: #e7533a;
#   color: #f1f1f1;
# }
# #T_d9495_row1_col2, #T_d9495_row9_col2, #T_d9495_row18_col2 {
#   background-color: #c3150e;
#   color: #f1f1f1;
# }
# #T_d9495_row2_col1, #T_d9495_row3_col0, #T_d9495_row3_col1, #T_d9495_row3_col2, #T_d9495_row4_col1, #T_d9495_row8_col1, #T_d9495_row16_col1, #T_d9495_row19_col0, #T_d9495_row19_col1, #T_d9495_row19_col2 {
#   background-color: #ed6145;
#   color: #f1f1f1;
# }
# #T_d9495_row2_col2, #T_d9495_row4_col2, #T_d9495_row8_col2, #T_d9495_row16_col2 {
#   background-color: #cc2116;
#   color: #f1f1f1;
# }
# #T_d9495_row5_col1, #T_d9495_row6_col0, #T_d9495_row6_col1, #T_d9495_row6_col2, #T_d9495_row15_col1, #T_d9495_row17_col1 {
#   background-color: #fdd5a0;
#   color: #000000;
# }
# #T_d9495_row5_col2, #T_d9495_row17_col2 {
#   background-color: #f4754f;
#   color: #f1f1f1;
# }
# #T_d9495_row12_col0, #T_d9495_row20_col0 {
#   background-color: #fdb57e;
#   color: #000000;
# }
# #T_d9495_row15_col0 {
#   background-color: #fff7ec;
#   color: #000000;
# }
# #T_d9495_row15_col2 {
#   background-color: #fee8c9;
#   color: #000000;
# }
# </style>
# <table id="T_d9495">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9495_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_d9495_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_d9495_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_d9495_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9495_level0_row0" class="row_heading level0 row0" >Uruguay</th>
#       <td id="T_d9495_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_d9495_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_d9495_row0_col2" class="data row0 col2" >1.00</td>
#       <td id="T_d9495_row0_col3" class="data row0 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row1" class="row_heading level0 row1" >amargo</th>
#       <td id="T_d9495_row1_col0" class="data row1 col0" >0.89</td>
#       <td id="T_d9495_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_d9495_row1_col2" class="data row1 col2" >0.94</td>
#       <td id="T_d9495_row1_col3" class="data row1 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row2" class="row_heading level0 row2" >aprender</th>
#       <td id="T_d9495_row2_col0" class="data row2 col0" >1.00</td>
#       <td id="T_d9495_row2_col1" class="data row2 col1" >0.88</td>
#       <td id="T_d9495_row2_col2" class="data row2 col2" >0.93</td>
#       <td id="T_d9495_row2_col3" class="data row2 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row3" class="row_heading level0 row3" >brillante</th>
#       <td id="T_d9495_row3_col0" class="data row3 col0" >0.88</td>
#       <td id="T_d9495_row3_col1" class="data row3 col1" >0.88</td>
#       <td id="T_d9495_row3_col2" class="data row3 col2" >0.88</td>
#       <td id="T_d9495_row3_col3" class="data row3 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row4" class="row_heading level0 row4" >comida</th>
#       <td id="T_d9495_row4_col0" class="data row4 col0" >1.00</td>
#       <td id="T_d9495_row4_col1" class="data row4 col1" >0.88</td>
#       <td id="T_d9495_row4_col2" class="data row4 col2" >0.93</td>
#       <td id="T_d9495_row4_col3" class="data row4 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row5" class="row_heading level0 row5" >comprar</th>
#       <td id="T_d9495_row5_col0" class="data row5 col0" >1.00</td>
#       <td id="T_d9495_row5_col1" class="data row5 col1" >0.75</td>
#       <td id="T_d9495_row5_col2" class="data row5 col2" >0.86</td>
#       <td id="T_d9495_row5_col3" class="data row5 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row6" class="row_heading level0 row6" >donde</th>
#       <td id="T_d9495_row6_col0" class="data row6 col0" >0.75</td>
#       <td id="T_d9495_row6_col1" class="data row6 col1" >0.75</td>
#       <td id="T_d9495_row6_col2" class="data row6 col2" >0.75</td>
#       <td id="T_d9495_row6_col3" class="data row6 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row7" class="row_heading level0 row7" >encontrar</th>
#       <td id="T_d9495_row7_col0" class="data row7 col0" >1.00</td>
#       <td id="T_d9495_row7_col1" class="data row7 col1" >1.00</td>
#       <td id="T_d9495_row7_col2" class="data row7 col2" >1.00</td>
#       <td id="T_d9495_row7_col3" class="data row7 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row8" class="row_heading level0 row8" >espumadera</th>
#       <td id="T_d9495_row8_col0" class="data row8 col0" >1.00</td>
#       <td id="T_d9495_row8_col1" class="data row8 col1" >0.88</td>
#       <td id="T_d9495_row8_col2" class="data row8 col2" >0.93</td>
#       <td id="T_d9495_row8_col3" class="data row8 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row9" class="row_heading level0 row9" >hijo</th>
#       <td id="T_d9495_row9_col0" class="data row9 col0" >0.89</td>
#       <td id="T_d9495_row9_col1" class="data row9 col1" >1.00</td>
#       <td id="T_d9495_row9_col2" class="data row9 col2" >0.94</td>
#       <td id="T_d9495_row9_col3" class="data row9 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row10" class="row_heading level0 row10" >hombre</th>
#       <td id="T_d9495_row10_col0" class="data row10 col0" >1.00</td>
#       <td id="T_d9495_row10_col1" class="data row10 col1" >1.00</td>
#       <td id="T_d9495_row10_col2" class="data row10 col2" >1.00</td>
#       <td id="T_d9495_row10_col3" class="data row10 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row11" class="row_heading level0 row11" >leche</th>
#       <td id="T_d9495_row11_col0" class="data row11 col0" >1.00</td>
#       <td id="T_d9495_row11_col1" class="data row11 col1" >1.00</td>
#       <td id="T_d9495_row11_col2" class="data row11 col2" >1.00</td>
#       <td id="T_d9495_row11_col3" class="data row11 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row12" class="row_heading level0 row12" >lejos</th>
#       <td id="T_d9495_row12_col0" class="data row12 col0" >0.80</td>
#       <td id="T_d9495_row12_col1" class="data row12 col1" >1.00</td>
#       <td id="T_d9495_row12_col2" class="data row12 col2" >0.89</td>
#       <td id="T_d9495_row12_col3" class="data row12 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row13" class="row_heading level0 row13" >mujer</th>
#       <td id="T_d9495_row13_col0" class="data row13 col0" >1.00</td>
#       <td id="T_d9495_row13_col1" class="data row13 col1" >1.00</td>
#       <td id="T_d9495_row13_col2" class="data row13 col2" >1.00</td>
#       <td id="T_d9495_row13_col3" class="data row13 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row14" class="row_heading level0 row14" >nacer</th>
#       <td id="T_d9495_row14_col0" class="data row14 col0" >1.00</td>
#       <td id="T_d9495_row14_col1" class="data row14 col1" >1.00</td>
#       <td id="T_d9495_row14_col2" class="data row14 col2" >1.00</td>
#       <td id="T_d9495_row14_col3" class="data row14 col3" >8.00</td>
#     </tr>
#     <tr>
#       <th id="T_d9495_level0_row15" class="row_heading level0 row15" >nave espacial</th>
#       <td id="T_d9495_row15_col0" class="data row15 col0" >0.67</td>

# %% [markdown]
# # Guardado de modelo

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\facur\\Desktop\\tesis_LSA\\codigos_datos_tesis\\Notebooks\\Lengua_Seña_CLF\\02_modelado\\XGBoost'

# %%
# Guardar modelo en joblib

#joblib.dump(modelxgb_base,'/00_modelos/03_xgboost_criterio_random_base.joblib')
# joblib.dump(modelxgb_opt,'../00_modelos/02_xgboost_criterio_random_10fr_with_face.joblib')
modelxgb_opt.save_model('../00_modelos/02_xgboost_criterio_random_10fr_with_face')
